# %% [markdown]
# <a href="https://colab.research.google.com/github/Mongsel8/Data-Anaysis/blob/main/Hyperopt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #HpyerOpt

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
 
from sklearn.datasets import load_iris
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer
import pandas as pd

iris = load_iris() 

lr_clf = LogisticRegression(solver='liblinear')
knn_clf = KNeighborsClassifier(n_neighbors=7)
gnb_clf = GaussianNB()
vo_clf = VotingClassifier(estimators=[('LR', lr_clf), ('KNN', knn_clf)], voting='soft')

X_train, X_test, y_train, y_test = train_test_split(
iris.data
, 
iris.target
, test_size=.2)

vo_clf.fit(X_train,y_train) 
pred = vo_clf.predict(X_test) 
print(accuracy_score(y_test, pred) )

from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, pred)
# Out:
# 0.9666666666666667
# array([[ 9,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  5]])

# %%
'''
from xgboost import plot_importance
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 12))
# 사이킷런 래퍼 클래스를 입력해도 무방. 
plot_importance(lgbm_clf, ax=ax)
'''
# Out:
# '\nfrom xgboost import plot_importance\nimport matplotlib.pyplot as plt\n\nfig, ax = plt.subplots(figsize=(10, 12))\n# 사이킷런 래퍼 클래스를 입력해도 무방. \nplot_importance(lgbm_clf, ax=ax)\n'

# %%
from sklearn.metrics import roc_auc_score, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    # ROC-AUC 추가 
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
from hyperopt import hp

search_space = {'x' : hp.quniform('x',-10,10,1), 'y' : hp.quniform('y',-15,15,1)}

# %%
from hyperopt import STATUS_OK

## 목적 함수 생성
## 변수, 검색 공간을 입력으로 받고, 특정 값을 반환하는 구조
def objective_func(search_space):
  
  x = search_space['x']
  y = search_space['y']
  retval = x ** 2 - 20 * y

  return retval

# %%
from hyperopt import fmin, tpe, Trials
import numpy as np

## 입력 결과를 저장할 객체 생성
trial_val = Trials()

## 목적 함수의 최솟값을 반환하는 최적 입력 변수를 5번 시도로 찾아냄
## fmin() 함수는 아래의 주요 인자를 가짐
best_01 = fmin(fn=objective_func,    ## 목적 함수
               space=search_space,   ## 검색 공간
               algo=tpe.suggest,     ## 베이지안 최적화 적용 알고리즘
               max_evals=20,         ## 입력 시도 횟수
               trials=trial_val,     ## 시도한 입력 값 및 입력 결과 저장
               #rstate=np.random.default_rng(seed=0)   ## fmin()을 시도할 때마다 동일한 결과를 가질 수 있도록 설정하는 랜덤 시드
               )
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 452.43it/s, best loss: -259.0]

# %%
print('best:', best_01)
trial_val.results
trial_val.vals
# Out:
# best: {'x': 1.0, 'y': 13.0}
# {'x': [4.0,
#   6.0,
#   7.0,
#   1.0,
#   -7.0,
#   -0.0,
#   9.0,
#   2.0,
#   -9.0,
#   -0.0,
#   1.0,
#   -9.0,
#   5.0,
#   6.0,
#   -9.0,
#   -5.0,
#   -6.0,
#   5.0,
#   -6.0,
#   7.0],
#  'y': [-7.0,
#   12.0,
#   0.0,
#   13.0,
#   -3.0,
#   -10.0,
#   6.0,
#   1.0,
#   -8.0,
#   10.0,
#   -11.0,
#   -8.0,
#   -5.0,
#   -1.0,
#   12.0,
#   6.0,
#   0.0,
#   -15.0,
#   -14.0,
#   13.0]}

# %% [markdown]
# #하이퍼파라메터 튜닝

# %%
dataset = load_breast_cancer()
features = dataset.data
labels = dataset.target

# %%
## 데이터를 Pandas DataFrame으로 로드
cancer_df = pd.DataFrame(data=features, columns=dataset.feature_names)
cancer_df['target'] = labels
cancer_df.head(5)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
## 학습 및 검증 데이터셋으로 데이터 분리
X_features = cancer_df.iloc[:, :-1]
y_label = cancer_df.iloc[:, -1]

# %%
## 학습, 검증용 데이터셋 비율 8 : 2
X_train, X_test, y_train, y_test = train_test_split(X_features, y_label, test_size=0.2, random_state=156)

## X_train, y_train을 다시 9 : 1 비율로 분리
## => XGBoost가 제공하는 교차 검증 성능 평가 및 조기 중단을 수행하기 위함
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=156)

# %%
## 모델 성능 평가 함수 선언
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):

    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)
    roc_auc = roc_auc_score(y_test, pred_proba)

    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, AUC: {4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
from hyperopt import hp

xgb_search_space = {
    'max_depth':hp.quniform('max_depth', 5, 20, 1),                     ## 정수형 하이퍼 파라미터 => quniform 사용
    'min_child_weight':hp.quniform('min_child_weight', 1, 2, 1),        ## 정수형 하이퍼 파라미터 => quniform 사용
    'learning_rate':hp.uniform('learning_rate', 0.01, 0.2),
    'colsample_bytree':hp.uniform('colsample_bytree', 0.5, 1),
}

# %%
## 2. 목적 함수 설정
## 검색 공간에서 설정한 하이퍼 파라미터들을 입력 받아서 XGBoost를 학습시키고, 평가 지표를 반환하도록 구성되어야 함

from sklearn.model_selection import cross_val_score  ## 교차 검증
from xgboost import XGBClassifier
from hyperopt import STATUS_OK

def objective_func(search_space):

  xgb_clf = XGBClassifier(
      n_estimators=100,
      max_depth=int(search_space['max_depth']),                ## int형으로 형변환 필요
      min_child_weight=int(search_space['min_child_weight']),  ## int형으로 형변환 필요
      learning_rate=search_space['learning_rate'], 
      colsample_bytree=search_space['colsample_bytree'],
      eval_metric='logloss'
  )

  accuracy = cross_val_score(xgb_clf, X_train, y_train, scoring='accuracy', cv=3)  ## 3개의 교차 검증 세트로 정확도 반환

  ## acc는 cv=3 개수만큼의 결과를 리스트로 가짐, 이를 평균하여 반환하되, -1을 곱함
  return {
      'loss':(-1) * np.mean(accuracy),
      'status':STATUS_OK
  }

# %%
## 3. fmin()을 사용하여 최적 하이퍼 파라미터 찾기

from hyperopt import fmin, tpe, Trials

trial_val = Trials() ## 결과 저장

best = fmin(
    fn=objective_func,
    space=xgb_search_space,
    algo=tpe.suggest,
    max_evals=50,    ## 최대 반복 횟수 지정
    trials=trial_val,
)
# Out:
# 100%|██████████| 50/50 [00:10<00:00,  4.77it/s, best loss: -0.9692401533635412]

# %%
## 획득한 최적의 하이퍼 파라미터를 이용하여 모델 선언

xgb_wrapper = XGBClassifier(
    n_estimators=400,
    learning_rate=round(best['learning_rate'], 5),
    max_depth=int(best['max_depth']),
    min_child_weight=int(best['min_child_weight']),
    colsample_bytree=round(best['colsample_bytree'], 5)
)

# %%
## early stopping

evals = [(X_tr, y_tr), (X_val, y_val)]

## model train

xgb_wrapper.fit(
    X_tr, y_tr,
    early_stopping_rounds=50,
    eval_metric='logloss',
    eval_set=evals,
    verbose=True
)
# Out:
# [0]	validation_0-logloss:0.551707	validation_1-logloss:0.610915
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 50 rounds.
# [1]	validation_0-logloss:0.449256	validation_1-logloss:0.547035
# [2]	validation_0-logloss:0.371838	validation_1-logloss:0.486076
# [3]	validation_0-logloss:0.314424	validation_1-logloss:0.455644
# [4]	validation_0-logloss:0.26539	validation_1-logloss:0.413263
# [5]	validation_0-logloss:0.226504	validation_1-logloss:0.385173
# [6]	validation_0-logloss:0.1959	validation_1-logloss:0.359044
# [7]	validation_0-logloss:0.171565	validation_1-logloss:0.337337
# [8]	validation_0-logloss:0.150198	validation_1-logloss:0.322163
# [9]	validation_0-logloss:0.131908	validation_1-logloss:0.31126
# [10]	validation_0-logloss:0.118272	validation_1-logloss:0.300637
# [11]	validation_0-logloss:0.104171	validation_1-logloss:0.289713
# [12]	validation_0-logloss:0.092854	validation_1-logloss:0.280076
# [13]	validation_0-logloss:0.084666	validation_1-logloss:0.277631
# [14]	validation_0-logloss:0.076926	validation_1-logloss:0.275963
# [15]	validation_0-logloss:0.069759	validation_1-logloss:0.266992
# [16]	validation_0-logloss:0.064591	validation_1-logloss:0.266811
# [17]	validation_0-logloss:0.0591	validation_1-logloss:0.262738
# [18]	validation_0-logloss:0.054399	validation_1-logloss:0.263545
# [19]	validation_0-logloss:0.050837	validation_1-logloss:0.264484
# [20]	validation_0-logloss:0.048268	validation_1-logloss:0.270588
# [21]	validation_0-logloss:0.045056	validation_1-logloss:0.268933
# [22]	validation_0-logloss:0.042737	validation_1-logloss:0.261399
# [23]	validation_0-logloss:0.040431	validation_1-logloss:0.261226
# [24]	validation_0-logloss:0.038684	validation_1-logloss:0.259158
# [25]	validation_0-logloss:0.036334	validation_1-logloss:0.263285
# [26]	validation_0-logloss:0.03452	validation_1-logloss:0.261332
# [27]	validation_0-logloss:0.032913	validation_1-logloss:0.262204
# [28]	validation_0-logloss:0.031766	validation_1-logloss:0.260935
# [29]	validation_0-logloss:0.030272	validation_1-logloss:0.263619
# [30]	validation_0-logloss:0.029034	validation_1-logloss:0.263432
# [31]	validation_0-logloss:0.028274	validation_1-logloss:0.262711
# [32]	validation_0-logloss:0.0274	validation_1-logloss:0.264388
# [33]	validation_0-logloss:0.026647	validation_1-logloss:0.261916
# [34]	validation_0-logloss:0.026035	validation_1-logloss:0.262225
# [35]	validation_0-logloss:0.025376	validation_1-logloss:0.259909
# [36]	validation_0-logloss:0.024584	validation_1-logloss:0.260148
# [37]	validation_0-logloss:0.024054	validation_1-logloss:0.259568
# [38]	validation_0-logloss:0.02377	validation_1-logloss:0.25873
# [39]	validation_0-logloss:0.023146	validation_1-logloss:0.259175
# [40]	validation_0-logloss:0.022925	validation_1-logloss:0.258528
# [41]	validation_0-logloss:0.022418	validation_1-logloss:0.259169
# [42]	validation_0-logloss:0.021886	validation_1-logloss:0.258213
# [43]	validation_0-logloss:0.021643	validation_1-logloss:0.255105
# [44]	validation_0-logloss:0.021415	validation_1-logloss:0.253398
# [45]	validation_0-logloss:0.021225	validation_1-logloss:0.25557
# [46]	validation_0-logloss:0.021038	validation_1-logloss:0.25406
# [47]	validation_0-logloss:0.020858	validation_1-logloss:0.254286
# [48]	validation_0-logloss:0.020408	validation_1-logloss:0.250518
# [49]	validation_0-logloss:0.020267	validation_1-logloss:0.249227
# [50]	validation_0-logloss:0.020082	validation_1-logloss:0.251414
# [51]	validation_0-logloss:0.019935	validation_1-logloss:0.251678
# [52]	validation_0-logloss:0.019782	validation_1-logloss:0.253716
# [53]	validation_0-logloss:0.019656	validation_1-logloss:0.253774
# [54]	validation_0-logloss:0.019528	validation_1-logloss:0.254536
# [55]	validation_0-logloss:0.0194	validation_1-logloss:0.253279
# [56]	validation_0-logloss:0.019282	validation_1-logloss:0.255789
# [57]	validation_0-logloss:0.019151	validation_1-logloss:0.252928
# [58]	validation_0-logloss:0.019019	validation_1-logloss:0.254897
# [59]	validation_0-logloss:0.018894	validation_1-logloss:0.254382
# [60]	validation_0-logloss:0.018782	validation_1-logloss:0.253199
# [61]	validation_0-logloss:0.018666	validation_1-logloss:0.255079
# [62]	validation_0-logloss:0.018545	validation_1-logloss:0.255342
# [63]	validation_0-logloss:0.018424	validation_1-logloss:0.252284
# [64]	validation_0-logloss:0.018305	validation_1-logloss:0.253398
# [65]	validation_0-logloss:0.018207	validation_1-logloss:0.255158
# [66]	validation_0-logloss:0.018092	validation_1-logloss:0.252176
# [67]	validation_0-logloss:0.017985	validation_1-logloss:0.249577
# [68]	validation_0-logloss:0.017876	validation_1-logloss:0.250677
# [69]	validation_0-logloss:0.01778	validation_1-logloss:0.247964
# [70]	validation_0-logloss:0.017674	validation_1-logloss:0.248236
# [71]	validation_0-logloss:0.017579	validation_1-logloss:0.249296
# [72]	validation_0-logloss:0.017488	validation_1-logloss:0.246673
# [73]	validation_0-logloss:0.017393	validation_1-logloss:0.248413
# [74]	validation_0-logloss:0.017304	validation_1-logloss:0.24603
# [75]	validation_0-logloss:0.017214	validation_1-logloss:0.246303
# [76]	validation_0-logloss:0.017126	validation_1-logloss:0.244954
# [77]	validation_0-logloss:0.017034	validation_1-logloss:0.246225
# [78]	validation_0-logloss:0.016945	validation_1-logloss:0.245122
# [79]	validation_0-logloss:0.016863	validation_1-logloss:0.244662
# [80]	validation_0-logloss:0.016783	validation_1-logloss:0.246877
# [81]	validation_0-logloss:0.016711	validation_1-logloss:0.24589
# [82]	validation_0-logloss:0.016631	validation_1-logloss:0.247126
# [83]	validation_0-logloss:0.016563	validation_1-logloss:0.246743
# [84]	validation_0-logloss:0.016483	validation_1-logloss:0.244224
# [85]	validation_0-logloss:0.016417	validation_1-logloss:0.246293
# [86]	validation_0-logloss:0.016338	validation_1-logloss:0.246246
# [87]	validation_0-logloss:0.016262	validation_1-logloss:0.243807
# [88]	validation_0-logloss:0.016189	validation_1-logloss:0.244655
# [89]	validation_0-logloss:0.016115	validation_1-logloss:0.244908
# [90]	validation_0-logloss:0.01605	validation_1-logloss:0.244198
# [91]	validation_0-logloss:0.015981	validation_1-logloss:0.244188
# [92]	validation_0-logloss:0.015911	validation_1-logloss:0.241851
# [93]	validation_0-logloss:0.015848	validation_1-logloss:0.240956
# [94]	validation_0-logloss:0.015784	validation_1-logloss:0.240965
# [95]	validation_0-logloss:0.015723	validation_1-logloss:0.242978
# [96]	validation_0-logloss:0.01566	validation_1-logloss:0.243215
# [97]	validation_0-logloss:0.015594	validation_1-logloss:0.244076
# [98]	validation_0-logloss:0.015527	validation_1-logloss:0.241796
# [99]	validation_0-logloss:0.015471	validation_1-logloss:0.242576
# [100]	validation_0-logloss:0.015414	validation_1-logloss:0.242161
# [101]	validation_0-logloss:0.015359	validation_1-logloss:0.241266
# [102]	validation_0-logloss:0.0153	validation_1-logloss:0.241411
# [103]	validation_0-logloss:0.015241	validation_1-logloss:0.240542
# [104]	validation_0-logloss:0.015187	validation_1-logloss:0.239874
# [105]	validation_0-logloss:0.015134	validation_1-logloss:0.240643
# [106]	validation_0-logloss:0.015083	validation_1-logloss:0.238701
# [107]	validation_0-logloss:0.015032	validation_1-logloss:0.238297
# [108]	validation_0-logloss:0.014974	validation_1-logloss:0.238463
# [109]	validation_0-logloss:0.014923	validation_1-logloss:0.237681
# [110]	validation_0-logloss:0.014872	validation_1-logloss:0.239541
# [111]	validation_0-logloss:0.014824	validation_1-logloss:0.239619
# [112]	validation_0-logloss:0.014773	validation_1-logloss:0.237688
# [113]	validation_0-logloss:0.014729	validation_1-logloss:0.238119
# [114]	validation_0-logloss:0.014679	validation_1-logloss:0.238902
# [115]	validation_0-logloss:0.014635	validation_1-logloss:0.238518
# [116]	validation_0-logloss:0.01459	validation_1-logloss:0.237895
# [117]	validation_0-logloss:0.014544	validation_1-logloss:0.237987
# [118]	validation_0-logloss:0.014497	validation_1-logloss:0.23723
# [119]	validation_0-logloss:0.014451	validation_1-logloss:0.239033
# [120]	validation_0-logloss:0.014408	validation_1-logloss:0.239175
# [121]	validation_0-logloss:0.014369	validation_1-logloss:0.238826
# [122]	validation_0-logloss:0.014327	validation_1-logloss:0.23959
# [123]	validation_0-logloss:0.014283	validation_1-logloss:0.238863
# [124]	validation_0-logloss:0.014244	validation_1-logloss:0.239264
# [125]	validation_0-logloss:0.0142	validation_1-logloss:0.238447
# [126]	validation_0-logloss:0.014161	validation_1-logloss:0.23865
# [127]	validation_0-logloss:0.01412	validation_1-logloss:0.240346
# [128]	validation_0-logloss:0.01408	validation_1-logloss:0.23863
# [129]	validation_0-logloss:0.014041	validation_1-logloss:0.23827
# [130]	validation_0-logloss:0.014004	validation_1-logloss:0.237708
# [131]	validation_0-logloss:0.013965	validation_1-logloss:0.237924
# [132]	validation_0-logloss:0.013926	validation_1-logloss:0.237256
# [133]	validation_0-logloss:0.013889	validation_1-logloss:0.238889
# [134]	validation_0-logloss:0.013852	validation_1-logloss:0.239276
# [135]	validation_0-logloss:0.013812	validation_1-logloss:0.238511
# [136]	validation_0-logloss:0.01378	validation_1-logloss:0.23791
# [137]	validation_0-logloss:0.013742	validation_1-logloss:0.237553
# [138]	validation_0-logloss:0.013705	validation_1-logloss:0.23831
# [139]	validation_0-logloss:0.013672	validation_1-logloss:0.238543
# [140]	validation_0-logloss:0.013638	validation_1-logloss:0.237998
# [141]	validation_0-logloss:0.013604	validation_1-logloss:0.237669
# [142]	validation_0-logloss:0.013571	validation_1-logloss:0.236981
# [143]	validation_0-logloss:0.013539	validation_1-logloss:0.237216
# [144]	validation_0-logloss:0.013506	validation_1-logloss:0.236611
# [145]	validation_0-logloss:0.013475	validation_1-logloss:0.236299
# [146]	validation_0-logloss:0.013443	validation_1-logloss:0.237019
# [147]	validation_0-logloss:0.013413	validation_1-logloss:0.236458
# [148]	validation_0-logloss:0.013385	validation_1-logloss:0.236696
# [149]	validation_0-logloss:0.013356	validation_1-logloss:0.236393
# [150]	validation_0-logloss:0.013328	validation_1-logloss:0.237076
# [151]	validation_0-logloss:0.013299	validation_1-logloss:0.236444
# [152]	validation_0-logloss:0.013271	validation_1-logloss:0.235911
# [153]	validation_0-logloss:0.013244	validation_1-logloss:0.235617
# [154]	validation_0-logloss:0.013218	validation_1-logloss:0.236235
# [155]	validation_0-logloss:0.01319	validation_1-logloss:0.236492
# [156]	validation_0-logloss:0.013164	validation_1-logloss:0.235902
# [157]	validation_0-logloss:0.013138	validation_1-logloss:0.235432
# [158]	validation_0-logloss:0.013114	validation_1-logloss:0.234947
# [159]	validation_0-logloss:0.013089	validation_1-logloss:0.235203
# [160]	validation_0-logloss:0.013064	validation_1-logloss:0.235483
# [161]	validation_0-logloss:0.013041	validation_1-logloss:0.235251
# [162]	validation_0-logloss:0.013019	validation_1-logloss:0.235895
# [163]	validation_0-logloss:0.012993	validation_1-logloss:0.235317
# [164]	validation_0-logloss:0.012971	validation_1-logloss:0.235953
# [165]	validation_0-logloss:0.01295	validation_1-logloss:0.235491
# [166]	validation_0-logloss:0.012927	validation_1-logloss:0.23576
# [167]	validation_0-logloss:0.012906	validation_1-logloss:0.23546
# [168]	validation_0-logloss:0.012884	validation_1-logloss:0.235019
# [169]	validation_0-logloss:0.012863	validation_1-logloss:0.235634
# [170]	validation_0-logloss:0.012844	validation_1-logloss:0.235192
# [171]	validation_0-logloss:0.012823	validation_1-logloss:0.235808
# [172]	validation_0-logloss:0.012801	validation_1-logloss:0.235276
# [173]	validation_0-logloss:0.012783	validation_1-logloss:0.235858
# [174]	validation_0-logloss:0.012766	validation_1-logloss:0.235462
# [175]	validation_0-logloss:0.012747	validation_1-logloss:0.235703
# [176]	validation_0-logloss:0.012727	validation_1-logloss:0.235202
# [177]	validation_0-logloss:0.01271	validation_1-logloss:0.235766
# [178]	validation_0-logloss:0.012693	validation_1-logloss:0.235364
# [179]	validation_0-logloss:0.012675	validation_1-logloss:0.235594
# [180]	validation_0-logloss:0.01266	validation_1-logloss:0.235218
# [181]	validation_0-logloss:0.012644	validation_1-logloss:0.234961
# [182]	validation_0-logloss:0.012627	validation_1-logloss:0.235196
# [183]	validation_0-logloss:0.012612	validation_1-logloss:0.234975
# [184]	validation_0-logloss:0.012595	validation_1-logloss:0.234517
# [185]	validation_0-logloss:0.012578	validation_1-logloss:0.234992
# [186]	validation_0-logloss:0.012563	validation_1-logloss:0.235206
# [187]	validation_0-logloss:0.012548	validation_1-logloss:0.234782
# [188]	validation_0-logloss:0.012533	validation_1-logloss:0.234303
# [189]	validation_0-logloss:0.012518	validation_1-logloss:0.234051
# [190]	validation_0-logloss:0.012503	validation_1-logloss:0.234599
# [191]	validation_0-logloss:0.012488	validation_1-logloss:0.234816
# [192]	validation_0-logloss:0.012473	validation_1-logloss:0.234601
# [193]	validation_0-logloss:0.012459	validation_1-logloss:0.234814
# [194]	validation_0-logloss:0.012446	validation_1-logloss:0.234414
# [195]	validation_0-logloss:0.012432	validation_1-logloss:0.233929
# [196]	validation_0-logloss:0.012419	validation_1-logloss:0.234136
# [197]	validation_0-logloss:0.012402	validation_1-logloss:0.234608
# [198]	validation_0-logloss:0.012388	validation_1-logloss:0.234397
# [199]	validation_0-logloss:0.012376	validation_1-logloss:0.23488
# [200]	validation_0-logloss:0.012365	validation_1-logloss:0.234664
# [201]	validation_0-logloss:0.012352	validation_1-logloss:0.23419
# [202]	validation_0-logloss:0.012341	validation_1-logloss:0.234003
# [203]	validation_0-logloss:0.012329	validation_1-logloss:0.234197
# [204]	validation_0-logloss:0.01232	validation_1-logloss:0.233908
# [205]	validation_0-logloss:0.012309	validation_1-logloss:0.233475
# [206]	validation_0-logloss:0.012298	validation_1-logloss:0.233665
# [207]	validation_0-logloss:0.012288	validation_1-logloss:0.234121
# [208]	validation_0-logloss:0.012276	validation_1-logloss:0.233911
# [209]	validation_0-logloss:0.012266	validation_1-logloss:0.233561
# [210]	validation_0-logloss:0.012257	validation_1-logloss:0.233741
# [211]	validation_0-logloss:0.012248	validation_1-logloss:0.233829
# [212]	validation_0-logloss:0.012237	validation_1-logloss:0.233399
# [213]	validation_0-logloss:0.012228	validation_1-logloss:0.233208
# [214]	validation_0-logloss:0.012218	validation_1-logloss:0.232863
# [215]	validation_0-logloss:0.012209	validation_1-logloss:0.233278
# [216]	validation_0-logloss:0.0122	validation_1-logloss:0.233371
# [217]	validation_0-logloss:0.012192	validation_1-logloss:0.233198
# [218]	validation_0-logloss:0.012192	validation_1-logloss:0.233198
# [219]	validation_0-logloss:0.012192	validation_1-logloss:0.233198
# [220]	validation_0-logloss:0.012192	validation_1-logloss:0.233198
# [221]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [222]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [223]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [224]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [225]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [226]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [227]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [228]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [229]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [230]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [231]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [232]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [233]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [234]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [235]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [236]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [237]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [238]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [239]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [240]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [241]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [242]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [243]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [244]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [245]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [246]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [247]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [248]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [249]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [250]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [251]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [252]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [253]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [254]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [255]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [256]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [257]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [258]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [259]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [260]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [261]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [262]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [263]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# [264]	validation_0-logloss:0.012192	validation_1-logloss:0.233197
# Stopping. Best iteration:
# [214]	validation_0-logloss:0.012218	validation_1-logloss:0.232863
# XGBClassifier(colsample_bytree=0.72884, learning_rate=0.18175, max_depth=12,
#               min_child_weight=2, n_estimators=400)

# %%
## eval

preds = xgb_wrapper.predict(X_test)
pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, preds, pred_proba)
# Out:
# 오차 행렬
# [[33  4]
#  [ 2 75]]
# 정확도: 0.9474, 정밀도: 0.9494, 재현율: 0.9740, F1: 0.9615, AUC: 0.9937

# %%
from hyperopt import hp
import numpy as np
xgb_search_space = {'max_depth': hp.quniform('max_depth', 5, 15, 1),'min_child_weight': hp.quniform('min_child_weight', 1, 6, 1),'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 0.95),'learning_rate': hp.uniform('learning_rate', 0.01, 0.2)} 
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from xgboost import XGBClassifier  
# 목적 함수 설정. 
# 추후 fmin()에서 입력된 search_space값으로 XGBClassifier 교차 검증 학습 후 -1* roc_auc 평균 값을 반환.  
def objective_func(search_space):
    xgb_clf = XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth'])
                           , min_child_weight=int(search_space['min_child_weight'])
                            , colsample_bytree=search_space['colsample_bytree']
                            , learning_rate=search_space['learning_rate']
                           )
    
    # 3개 k-fold 방식으로 평가된 roc_auc 지표를 담는 list
    roc_auc_list= []
    
    # 3개 k-fold방식 적용 
    kf = KFold(n_splits=3)
    # X_train을 다시 학습과 검증용 데이터로 분리
    for tr_index, val_index in kf.split(X_train):
        # kf.split(X_train)으로 추출된 학습과 검증 index값으로 학습과 검증 데이터 세트 분리 
        X_tr, y_tr = X_train.iloc[tr_index], y_train.iloc[tr_index]
        X_val, y_val = X_train.iloc[val_index], y_train.iloc[val_index]
        # early stopping은 30회로 설정하고 추출된 학습과 검증 데이터로 XGBClassifier 학습 수행.
        xgb_clf.fit(X_tr, y_tr, early_stopping_rounds=30, eval_metric='auc'
                   , eval_set=[(X_tr, y_tr), (X_val, y_val)])
    
        # 1로 예측한 확률값 추출후 roc auc 계산하고 평균 roc auc 계산을 위해 list에 결과값 담음. 
        score = roc_auc_score(y_val, xgb_clf.predict_proba(X_val)[:, 1])
        roc_auc_list.append(score)
    
    # 3개 k-fold로 계산된 roc_auc값의 평균값을 반환하되, 
    # HyperOpt는 목적함수의 최소값을 위한 입력값을 찾으므로 -1을 곱한 뒤 반환. 
    return -1 * np.mean(roc_auc_list) 
from hyperopt import fmin, tpe, Trials

trials = Trials()
SEED = 30
# fmin()함수를 호출. max_evals지정된 횟수만큼 반복 후 목적함수의 최소값을 가지는 최적 입력값 추출.
best = fmin(fn=objective_func,
            space=xgb_search_space,
            algo=tpe.suggest,
            max_evals=50, # 최대 반복 횟수를 지정합니다.
            trials=trials)

print('best:', best)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [10]	validation_0-auc:0.995699	validation_1-auc:0.986812
#
# [11]	validation_0-auc:0.996307	validation_1-auc:0.992203
#
# [12]	validation_0-auc:0.996712	validation_1-auc:0.992684
#
# [13]	validation_0-auc:0.996892	validation_1-auc:0.993454
#
# [14]	validation_0-auc:0.997028	validation_1-auc:0.994032
#
# [15]	validation_0-auc:0.997478	validation_1-auc:0.993261
#
# [16]	validation_0-auc:0.997658	validation_1-auc:0.993069
#
# [17]	validation_0-auc:0.997568	validation_1-auc:0.992876
#
# [18]	validation_0-auc:0.997658	validation_1-auc:0.992491
#
# [19]	validation_0-auc:0.997883	validation_1-auc:0.991529
#
# [20]	validation_0-auc:0.997838	validation_1-auc:0.991529
#
# [21]	validation_0-auc:0.997883	validation_1-auc:0.991914
#
# [22]	validation_0-auc:0.998199	validation_1-auc:0.991914
#
# [23]	validation_0-auc:0.998154	validation_1-auc:0.991914
#
# [24]	validation_0-auc:0.998424	validation_1-auc:0.991914
#
# [25]	validation_0-auc:0.998604	validation_1-auc:0.992106
#
# [26]	validation_0-auc:0.998739	validation_1-auc:0.992106
#
# [27]	validation_0-auc:0.998919	validation_1-auc:0.991529
#
# [28]	validation_0-auc:0.998964	validation_1-auc:0.991721
#
# [29]	validation_0-auc:0.999009	validation_1-auc:0.992491
#
# [30]	validation_0-auc:0.999054	validation_1-auc:0.993069
#
# [31]	validation_0-auc:0.999009	validation_1-auc:0.993261
#
# [32]	validation_0-auc:0.999189	validation_1-auc:0.993261
#
# [33]	validation_0-auc:0.999279	validation_1-auc:0.993261
#
# [34]	validation_0-auc:0.999279	validation_1-auc:0.993839
#
# [35]	validation_0-auc:0.999279	validation_1-auc:0.993647
#
# [36]	validation_0-auc:0.999279	validation_1-auc:0.993647
#
# [37]	validation_0-auc:0.999324	validation_1-auc:0.993647
#
# [38]	validation_0-auc:0.999279	validation_1-auc:0.993647
#
# [39]	validation_0-auc:0.99937	validation_1-auc:0.993647
#
# [40]	validation_0-auc:0.999415	validation_1-auc:0.993839
#
# [41]	validation_0-auc:0.999415	validation_1-auc:0.993839
#
# [42]	validation_0-auc:0.999415	validation_1-auc:0.993454
#
# [43]	validation_0-auc:0.99946	validation_1-auc:0.993647
#
# [44]	validation_0-auc:0.99946	validation_1-auc:0.993647
#
# Stopping. Best iteration:
# [14]	validation_0-auc:0.997028	validation_1-auc:0.994032
#
#
# [0]	validation_0-auc:0.977019	validation_1-auc:0.947239
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.987115	validation_1-auc:0.965373
#
# [2]	validation_0-auc:0.988452	validation_1-auc:0.972207
#
# [3]	validation_0-auc:0.988636	validation_1-auc:0.972207
#
# [4]	validation_0-auc:0.988982	validation_1-auc:0.974394
#
# [5]	validation_0-auc:0.98912	validation_1-auc:0.974303
#
# [6]	validation_0-auc:0.991679	validation_1-auc:0.977766
#
# [7]	validation_0-auc:0.991679	validation_1-auc:0.977948
#
# [8]	validation_0-auc:0.992002	validation_1-auc:0.979132
#
# [9]	validation_0-auc:0.992878	validation_1-auc:0.978586
#
# [10]	validation_0-auc:0.993592	validation_1-auc:0.97813
#
# [11]	validation_0-auc:0.993408	validation_1-auc:0.977037
#
# [12]	validation_0-auc:0.994284	validation_1-auc:0.977948
#
# [13]	validation_0-auc:0.993984	validation_1-auc:0.979497
#
# [14]	validation_0-auc:0.994353	validation_1-auc:0.979953
#
# [15]	validation_0-auc:0.994307	validation_1-auc:0.980135
#
# [16]	validation_0-auc:0.994537	validation_1-auc:0.981046
#
# [17]	validation_0-auc:0.994399	validation_1-auc:0.981046
#
# [18]	validation_0-auc:0.994399	validation_1-auc:0.98214
#
# [19]	validation_0-auc:0.994353	validation_1-auc:0.983051
#
# [20]	validation_0-auc:0.994537	validation_1-auc:0.983598
#
# [21]	validation_0-auc:0.995183	validation_1-auc:0.983506
#
# [22]	validation_0-auc:0.995367	validation_1-auc:0.983689
#
# [23]	validation_0-auc:0.995528	validation_1-auc:0.985876
#
# [24]	validation_0-auc:0.995851	validation_1-auc:0.985329
#
# [25]	validation_0-auc:0.996174	validation_1-auc:0.986969
#
# [26]	validation_0-auc:0.996358	validation_1-auc:0.987334
#
# [27]	validation_0-auc:0.996358	validation_1-auc:0.987698
#
# [28]	validation_0-auc:0.996404	validation_1-auc:0.987334
#
# [29]	validation_0-auc:0.99622	validation_1-auc:0.986787
#
# [30]	validation_0-auc:0.99622	validation_1-auc:0.987516
#
# [31]	validation_0-auc:0.996404	validation_1-auc:0.987334
#
# [32]	validation_0-auc:0.996312	validation_1-auc:0.98788
#
# [33]	validation_0-auc:0.996358	validation_1-auc:0.988063
#
# [34]	validation_0-auc:0.99645	validation_1-auc:0.988063
#
# [35]	validation_0-auc:0.996404	validation_1-auc:0.988609
#
# [36]	validation_0-auc:0.996819	validation_1-auc:0.988245
#
# [37]	validation_0-auc:0.996773	validation_1-auc:0.988245
#
# [38]	validation_0-auc:0.996819	validation_1-auc:0.988609
#
# [39]	validation_0-auc:0.99728	validation_1-auc:0.988974
#
# [40]	validation_0-auc:0.997326	validation_1-auc:0.989338
#
# [41]	validation_0-auc:0.997511	validation_1-auc:0.989703
#
# [42]	validation_0-auc:0.997649	validation_1-auc:0.989703
#
# [43]	validation_0-auc:0.997787	validation_1-auc:0.990888
#
# [44]	validation_0-auc:0.998156	validation_1-auc:0.990159
#
# [45]	validation_0-auc:0.99834	validation_1-auc:0.990523
#
# [46]	validation_0-auc:0.998479	validation_1-auc:0.990159
#
# [47]	validation_0-auc:0.998433	validation_1-auc:0.989794
#
# [48]	validation_0-auc:0.998617	validation_1-auc:0.990888
#
# [49]	validation_0-auc:0.998617	validation_1-auc:0.991252
#
# [50]	validation_0-auc:0.998709	validation_1-auc:0.991617
#
# [51]	validation_0-auc:0.998801	validation_1-auc:0.991617
#
# [52]	validation_0-auc:0.998663	validation_1-auc:0.991252
#
# [53]	validation_0-auc:0.998801	validation_1-auc:0.991434
#
# [54]	validation_0-auc:0.998894	validation_1-auc:0.991252
#
# [55]	validation_0-auc:0.998894	validation_1-auc:0.991252
#
# [56]	validation_0-auc:0.998894	validation_1-auc:0.99107
#
# [57]	validation_0-auc:0.998894	validation_1-auc:0.991252
#
# [58]	validation_0-auc:0.998894	validation_1-auc:0.991252
#
# [59]	validation_0-auc:0.998894	validation_1-auc:0.99107
#
# [60]	validation_0-auc:0.998986	validation_1-auc:0.990888
#
# [61]	validation_0-auc:0.99894	validation_1-auc:0.99107
#
# [62]	validation_0-auc:0.998894	validation_1-auc:0.991252
#
# [63]	validation_0-auc:0.99894	validation_1-auc:0.99107
#
# [64]	validation_0-auc:0.998847	validation_1-auc:0.991252
#
# [65]	validation_0-auc:0.998847	validation_1-auc:0.991617
#
# [66]	validation_0-auc:0.998801	validation_1-auc:0.991981
#
# [67]	validation_0-auc:0.998847	validation_1-auc:0.992163
#
# [68]	validation_0-auc:0.998847	validation_1-auc:0.992528
#
# [69]	validation_0-auc:0.998847	validation_1-auc:0.99271
#
# [70]	validation_0-auc:0.998847	validation_1-auc:0.992528
#
# [71]	validation_0-auc:0.998847	validation_1-auc:0.992528
#
# [72]	validation_0-auc:0.998847	validation_1-auc:0.99271
#
# [73]	validation_0-auc:0.998801	validation_1-auc:0.99271
#
# [74]	validation_0-auc:0.998755	validation_1-auc:0.992892
#
# [75]	validation_0-auc:0.998755	validation_1-auc:0.992892
#
# [76]	validation_0-auc:0.998755	validation_1-auc:0.99271
#
# [77]	validation_0-auc:0.998709	validation_1-auc:0.99271
#
# [78]	validation_0-auc:0.998755	validation_1-auc:0.992892
#
# [79]	validation_0-auc:0.998755	validation_1-auc:0.992892
#
# [80]	validation_0-auc:0.998663	validation_1-auc:0.992892
#
# [81]	validation_0-auc:0.998663	validation_1-auc:0.99271
#
# [82]	validation_0-auc:0.998663	validation_1-auc:0.99271
#
# [83]	validation_0-auc:0.998663	validation_1-auc:0.99271
#
# [84]	validation_0-auc:0.998663	validation_1-auc:0.99271
#
# [85]	validation_0-auc:0.998755	validation_1-auc:0.992892
#
# [86]	validation_0-auc:0.998755	validation_1-auc:0.992892
#
# [87]	validation_0-auc:0.998709	validation_1-auc:0.992892
#
# [88]	validation_0-auc:0.998709	validation_1-auc:0.992892
#
# [89]	validation_0-auc:0.998709	validation_1-auc:0.992892
#
# [90]	validation_0-auc:0.998663	validation_1-auc:0.992892
#
# [91]	validation_0-auc:0.998755	validation_1-auc:0.992892
#
# [92]	validation_0-auc:0.998755	validation_1-auc:0.992892
#
# [93]	validation_0-auc:0.998755	validation_1-auc:0.992892
#
# [94]	validation_0-auc:0.998617	validation_1-auc:0.992892
#
# [95]	validation_0-auc:0.998755	validation_1-auc:0.992892
#
# [96]	validation_0-auc:0.998801	validation_1-auc:0.992892
#
# [97]	validation_0-auc:0.998801	validation_1-auc:0.992892
#
# [98]	validation_0-auc:0.99894	validation_1-auc:0.992892
#
# [99]	validation_0-auc:0.99894	validation_1-auc:0.992892
#
# [0]	validation_0-auc:0.981839	validation_1-auc:0.951489
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.992521	validation_1-auc:0.968076
#
# [2]	validation_0-auc:0.992918	validation_1-auc:0.986535
#
# [3]	validation_0-auc:0.993268	validation_1-auc:0.988764
#
# [4]	validation_0-auc:0.993268	validation_1-auc:0.988764
#
# [5]	validation_0-auc:0.993643	validation_1-auc:0.988229
#
# [6]	validation_0-auc:0.996611	validation_1-auc:0.987159
#
# [7]	validation_0-auc:0.996611	validation_1-auc:0.986981
#
# [8]	validation_0-auc:0.996471	validation_1-auc:0.986089
#
# [9]	validation_0-auc:0.996658	validation_1-auc:0.983592
#
# [10]	validation_0-auc:0.996471	validation_1-auc:0.983235
#
# [11]	validation_0-auc:0.996377	validation_1-auc:0.983235
#
# [12]	validation_0-auc:0.996494	validation_1-auc:0.981452
#
# [13]	validation_0-auc:0.996517	validation_1-auc:0.983057
#
# [14]	validation_0-auc:0.996658	validation_1-auc:0.984127
#
# [15]	validation_0-auc:0.996891	validation_1-auc:0.985019
#
# [16]	validation_0-auc:0.997032	validation_1-auc:0.98377
#
# [17]	validation_0-auc:0.997265	validation_1-auc:0.982879
#
# [18]	validation_0-auc:0.997522	validation_1-auc:0.9827
#
# [19]	validation_0-auc:0.997616	validation_1-auc:0.982879
#
# [20]	validation_0-auc:0.997709	validation_1-auc:0.982343
#
# [21]	validation_0-auc:0.997709	validation_1-auc:0.981987
#
# [22]	validation_0-auc:0.997663	validation_1-auc:0.981452
#
# [23]	validation_0-auc:0.997663	validation_1-auc:0.981452
#
# [24]	validation_0-auc:0.997663	validation_1-auc:0.981273
#
# [25]	validation_0-auc:0.997663	validation_1-auc:0.980917
#
# [26]	validation_0-auc:0.997569	validation_1-auc:0.981095
#
# [27]	validation_0-auc:0.997616	validation_1-auc:0.980738
#
# [28]	validation_0-auc:0.997569	validation_1-auc:0.980382
#
# [29]	validation_0-auc:0.997663	validation_1-auc:0.97949
#
# [30]	validation_0-auc:0.997639	validation_1-auc:0.980382
#
# [31]	validation_0-auc:0.997756	validation_1-auc:0.980738
#
# [32]	validation_0-auc:0.997756	validation_1-auc:0.980382
#
# [33]	validation_0-auc:0.99785	validation_1-auc:0.980917
#
# Stopping. Best iteration:
# [3]	validation_0-auc:0.993268	validation_1-auc:0.988764
#
#
# [0]	validation_0-auc:0.96897	validation_1-auc:0.960724
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.980251	validation_1-auc:0.969099
#
# [2]	validation_0-auc:0.988898	validation_1-auc:0.978052
#
# [3]	validation_0-auc:0.988493	validation_1-auc:0.980651
#
# [4]	validation_0-auc:0.98802	validation_1-auc:0.98248
#
# [5]	validation_0-auc:0.98757	validation_1-auc:0.98171
#
# [6]	validation_0-auc:0.989732	validation_1-auc:0.984213
#
# [7]	validation_0-auc:0.989484	validation_1-auc:0.98402
#
# [8]	validation_0-auc:0.990655	validation_1-auc:0.984983
#
# [9]	validation_0-auc:0.990497	validation_1-auc:0.985175
#
# [10]	validation_0-auc:0.992884	validation_1-auc:0.984405
#
# [11]	validation_0-auc:0.992456	validation_1-auc:0.98402
#
# [12]	validation_0-auc:0.992704	validation_1-auc:0.982961
#
# [13]	validation_0-auc:0.992974	validation_1-auc:0.983057
#
# [14]	validation_0-auc:0.993199	validation_1-auc:0.989892
#
# [15]	validation_0-auc:0.994415	validation_1-auc:0.9897
#
# [16]	validation_0-auc:0.994956	validation_1-auc:0.991047
#
# [17]	validation_0-auc:0.995271	validation_1-auc:0.99201
#
# [18]	validation_0-auc:0.995361	validation_1-auc:0.993069
#
# [19]	validation_0-auc:0.995812	validation_1-auc:0.992684
#
# [20]	validation_0-auc:0.995992	validation_1-auc:0.993839
#
# [21]	validation_0-auc:0.995902	validation_1-auc:0.993839
#
# [22]	validation_0-auc:0.995992	validation_1-auc:0.994417
#
# [23]	validation_0-auc:0.996397	validation_1-auc:0.994032
#
# [24]	validation_0-auc:0.996667	validation_1-auc:0.994032
#
# [25]	validation_0-auc:0.996712	validation_1-auc:0.994032
#
# [26]	validation_0-auc:0.996892	validation_1-auc:0.993839
#
# [27]	validation_0-auc:0.997253	validation_1-auc:0.993839
#
# [28]	validation_0-auc:0.997298	validation_1-auc:0.994224
#
# [29]	validation_0-auc:0.997208	validation_1-auc:0.994224
#
# [30]	validation_0-auc:0.997388	validation_1-auc:0.994609
#
# [31]	validation_0-auc:0.997748	validation_1-auc:0.994994
#
# [32]	validation_0-auc:0.997748	validation_1-auc:0.995187
#
# [33]	validation_0-auc:0.997793	validation_1-auc:0.995187
#
# [34]	validation_0-auc:0.997883	validation_1-auc:0.995379
#
# [35]	validation_0-auc:0.998018	validation_1-auc:0.995572
#
# [36]	validation_0-auc:0.998063	validation_1-auc:0.995379
#
# [37]	validation_0-auc:0.998063	validation_1-auc:0.995572
#
# [38]	validation_0-auc:0.998108	validation_1-auc:0.995572
#
# [39]	validation_0-auc:0.998244	validation_1-auc:0.995572
#
# [40]	validation_0-auc:0.998334	validation_1-auc:0.995572
#
# [41]	validation_0-auc:0.998424	validation_1-auc:0.995572
#
# [42]	validation_0-auc:0.998559	validation_1-auc:0.995764
#
# [43]	validation_0-auc:0.998559	validation_1-auc:0.995764
#
# [44]	validation_0-auc:0.998559	validation_1-auc:0.995764
#
# [45]	validation_0-auc:0.998739	validation_1-auc:0.996149
#
# [46]	validation_0-auc:0.998739	validation_1-auc:0.995764
#
# [47]	validation_0-auc:0.998739	validation_1-auc:0.995957
#
# [48]	validation_0-auc:0.998739	validation_1-auc:0.995957
#
# [49]	validation_0-auc:0.998649	validation_1-auc:0.996149
#
# [50]	validation_0-auc:0.998874	validation_1-auc:0.995957
#
# [51]	validation_0-auc:0.998919	validation_1-auc:0.996149
#
# [52]	validation_0-auc:0.998784	validation_1-auc:0.996149
#
# [53]	validation_0-auc:0.999009	validation_1-auc:0.996149
#
# [54]	validation_0-auc:0.999009	validation_1-auc:0.996149
#
# [55]	validation_0-auc:0.999054	validation_1-auc:0.996342
#
# [56]	validation_0-auc:0.999009	validation_1-auc:0.996342
#
# [57]	validation_0-auc:0.999054	validation_1-auc:0.996149
#
# [58]	validation_0-auc:0.999054	validation_1-auc:0.996149
#
# [59]	validation_0-auc:0.999054	validation_1-auc:0.996149
#
# [60]	validation_0-auc:0.999099	validation_1-auc:0.996342
#
# [61]	validation_0-auc:0.999144	validation_1-auc:0.996149
#
# [62]	validation_0-auc:0.999144	validation_1-auc:0.996342
#
# [63]	validation_0-auc:0.999099	validation_1-auc:0.996534
#
# [64]	validation_0-auc:0.999144	validation_1-auc:0.996534
#
# [65]	validation_0-auc:0.999144	validation_1-auc:0.996534
#
# [66]	validation_0-auc:0.999189	validation_1-auc:0.996727
#
# [67]	validation_0-auc:0.999144	validation_1-auc:0.996727
#
# [68]	validation_0-auc:0.999144	validation_1-auc:0.996727
#
# [69]	validation_0-auc:0.999144	validation_1-auc:0.996727
#
# [70]	validation_0-auc:0.999144	validation_1-auc:0.996727
#
# [71]	validation_0-auc:0.999234	validation_1-auc:0.996727
#
# [72]	validation_0-auc:0.999144	validation_1-auc:0.996727
#
# [73]	validation_0-auc:0.999234	validation_1-auc:0.996727
#
# [74]	validation_0-auc:0.999189	validation_1-auc:0.99692
#
# [75]	validation_0-auc:0.999189	validation_1-auc:0.99692
#
# [76]	validation_0-auc:0.999144	validation_1-auc:0.996534
#
# [77]	validation_0-auc:0.999144	validation_1-auc:0.99692
#
# [78]	validation_0-auc:0.999189	validation_1-auc:0.996534
#
# [79]	validation_0-auc:0.999189	validation_1-auc:0.996534
#
# [80]	validation_0-auc:0.999234	validation_1-auc:0.99692
#
# [81]	validation_0-auc:0.999234	validation_1-auc:0.99692
#
# [82]	validation_0-auc:0.999234	validation_1-auc:0.99692
#
# [83]	validation_0-auc:0.999279	validation_1-auc:0.996727
#
# [84]	validation_0-auc:0.999279	validation_1-auc:0.996727
#
# [85]	validation_0-auc:0.999279	validation_1-auc:0.996727
#
# [86]	validation_0-auc:0.999279	validation_1-auc:0.996727
#
# [87]	validation_0-auc:0.999279	validation_1-auc:0.996727
#
# [88]	validation_0-auc:0.999234	validation_1-auc:0.996727
#
# [89]	validation_0-auc:0.999234	validation_1-auc:0.996727
#
# [90]	validation_0-auc:0.999234	validation_1-auc:0.996727
#
# [91]	validation_0-auc:0.999234	validation_1-auc:0.99692
#
# [92]	validation_0-auc:0.999279	validation_1-auc:0.99692
#
# [93]	validation_0-auc:0.999234	validation_1-auc:0.996727
#
# [94]	validation_0-auc:0.999234	validation_1-auc:0.996727
#
# [95]	validation_0-auc:0.999234	validation_1-auc:0.996727
#
# [96]	validation_0-auc:0.999234	validation_1-auc:0.996727
#
# [97]	validation_0-auc:0.999279	validation_1-auc:0.996727
#
# [98]	validation_0-auc:0.999279	validation_1-auc:0.99692
#
# [99]	validation_0-auc:0.999279	validation_1-auc:0.99692
#
# [0]	validation_0-auc:0.989259	validation_1-auc:0.958083
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.991679	validation_1-auc:0.967742
#
# [2]	validation_0-auc:0.992716	validation_1-auc:0.975761
#
# [3]	validation_0-auc:0.992601	validation_1-auc:0.974576
#
# [4]	validation_0-auc:0.992808	validation_1-auc:0.975032
#
# [5]	validation_0-auc:0.992739	validation_1-auc:0.978404
#
# [6]	validation_0-auc:0.997211	validation_1-auc:0.984053
#
# [7]	validation_0-auc:0.996796	validation_1-auc:0.982869
#
# [8]	validation_0-auc:0.99758	validation_1-auc:0.982504
#
# [9]	validation_0-auc:0.998041	validation_1-auc:0.986149
#
# [10]	validation_0-auc:0.998363	validation_1-auc:0.986058
#
# [11]	validation_0-auc:0.998502	validation_1-auc:0.986878
#
# [12]	validation_0-auc:0.998778	validation_1-auc:0.986696
#
# [13]	validation_0-auc:0.998963	validation_1-auc:0.98788
#
# [14]	validation_0-auc:0.998871	validation_1-auc:0.987516
#
# [15]	validation_0-auc:0.99917	validation_1-auc:0.987972
#
# [16]	validation_0-auc:0.999262	validation_1-auc:0.988154
#
# [17]	validation_0-auc:0.999216	validation_1-auc:0.988701
#
# [18]	validation_0-auc:0.999355	validation_1-auc:0.989065
#
# [19]	validation_0-auc:0.999355	validation_1-auc:0.989065
#
# [20]	validation_0-auc:0.999585	validation_1-auc:0.988883
#
# [21]	validation_0-auc:0.999585	validation_1-auc:0.988518
#
# [22]	validation_0-auc:0.99977	validation_1-auc:0.988518
#
# [23]	validation_0-auc:0.99977	validation_1-auc:0.98943
#
# [24]	validation_0-auc:0.999862	validation_1-auc:0.989247
#
# [25]	validation_0-auc:0.999862	validation_1-auc:0.990159
#
# [26]	validation_0-auc:0.999862	validation_1-auc:0.990159
#
# [27]	validation_0-auc:0.999862	validation_1-auc:0.990523
#
# [28]	validation_0-auc:0.999862	validation_1-auc:0.990341
#
# [29]	validation_0-auc:0.999862	validation_1-auc:0.990341
#
# [30]	validation_0-auc:0.999862	validation_1-auc:0.990341
#
# [31]	validation_0-auc:0.999908	validation_1-auc:0.990341
#
# [32]	validation_0-auc:0.999908	validation_1-auc:0.989976
#
# [33]	validation_0-auc:0.999908	validation_1-auc:0.990341
#
# [34]	validation_0-auc:0.999908	validation_1-auc:0.990705
#
# [35]	validation_0-auc:0.999908	validation_1-auc:0.990705
#
# [36]	validation_0-auc:0.999908	validation_1-auc:0.99107
#
# [37]	validation_0-auc:0.999908	validation_1-auc:0.990705
#
# [38]	validation_0-auc:0.999908	validation_1-auc:0.990705
#
# [39]	validation_0-auc:0.999908	validation_1-auc:0.990705
#
# [40]	validation_0-auc:0.999908	validation_1-auc:0.990523
#
# [41]	validation_0-auc:0.999908	validation_1-auc:0.989794
#
# [42]	validation_0-auc:0.999908	validation_1-auc:0.989612
#
# [43]	validation_0-auc:0.999908	validation_1-auc:0.989612
#
# [44]	validation_0-auc:0.999908	validation_1-auc:0.990341
#
# [45]	validation_0-auc:0.999908	validation_1-auc:0.989976
#
# [46]	validation_0-auc:0.999908	validation_1-auc:0.990341
#
# [47]	validation_0-auc:0.999908	validation_1-auc:0.990888
#
# [48]	validation_0-auc:0.999908	validation_1-auc:0.991252
#
# [49]	validation_0-auc:0.999908	validation_1-auc:0.990888
#
# [50]	validation_0-auc:0.999954	validation_1-auc:0.991434
#
# [51]	validation_0-auc:0.999954	validation_1-auc:0.991434
#
# [52]	validation_0-auc:0.999954	validation_1-auc:0.991252
#
# [53]	validation_0-auc:0.999954	validation_1-auc:0.99107
#
# [54]	validation_0-auc:0.999954	validation_1-auc:0.99107
#
# [55]	validation_0-auc:0.999954	validation_1-auc:0.991252
#
# [56]	validation_0-auc:0.999954	validation_1-auc:0.991252
#
# [57]	validation_0-auc:0.999954	validation_1-auc:0.991252
#
# [58]	validation_0-auc:0.999954	validation_1-auc:0.991252
#
# [59]	validation_0-auc:0.999954	validation_1-auc:0.991252
#
# [60]	validation_0-auc:0.999954	validation_1-auc:0.991252
#
# [61]	validation_0-auc:0.999954	validation_1-auc:0.991434
#
# [62]	validation_0-auc:0.999954	validation_1-auc:0.991434
#
# [63]	validation_0-auc:0.999954	validation_1-auc:0.991617
#
# [64]	validation_0-auc:0.999954	validation_1-auc:0.991617
#
# [65]	validation_0-auc:0.999954	validation_1-auc:0.991617
#
# [66]	validation_0-auc:0.999954	validation_1-auc:0.991617
#
# [67]	validation_0-auc:0.999954	validation_1-auc:0.991617
#
# [68]	validation_0-auc:0.999954	validation_1-auc:0.991617
#
# [69]	validation_0-auc:0.999954	validation_1-auc:0.991617
#
# [70]	validation_0-auc:0.999954	validation_1-auc:0.991617
#
# [71]	validation_0-auc:0.999954	validation_1-auc:0.991799
#
# [72]	validation_0-auc:0.999954	validation_1-auc:0.991981
#
# [73]	validation_0-auc:0.999954	validation_1-auc:0.991799
#
# [74]	validation_0-auc:0.999954	validation_1-auc:0.991617
#
# [75]	validation_0-auc:0.999954	validation_1-auc:0.991981
#
# [76]	validation_0-auc:0.999954	validation_1-auc:0.991617
#
# [77]	validation_0-auc:0.999954	validation_1-auc:0.991617
#
# [78]	validation_0-auc:0.999954	validation_1-auc:0.991799
#
# [79]	validation_0-auc:0.999954	validation_1-auc:0.991799
#
# [80]	validation_0-auc:0.999954	validation_1-auc:0.991981
#
# [81]	validation_0-auc:0.999954	validation_1-auc:0.991799
#
# [82]	validation_0-auc:0.999954	validation_1-auc:0.992163
#
# [83]	validation_0-auc:0.999954	validation_1-auc:0.992163
#
# [84]	validation_0-auc:0.999954	validation_1-auc:0.991981
#
# [85]	validation_0-auc:0.999954	validation_1-auc:0.991799
#
# [86]	validation_0-auc:0.999954	validation_1-auc:0.991799
#
# [87]	validation_0-auc:0.999954	validation_1-auc:0.991617
#
# [88]	validation_0-auc:0.999954	validation_1-auc:0.991799
#
# [89]	validation_0-auc:0.999954	validation_1-auc:0.991981
#
# [90]	validation_0-auc:1	validation_1-auc:0.991799
#
# [91]	validation_0-auc:1	validation_1-auc:0.991799
#
# [92]	validation_0-auc:1	validation_1-auc:0.992346
#
# [93]	validation_0-auc:1	validation_1-auc:0.992528
#
# [94]	validation_0-auc:1	validation_1-auc:0.992892
#
# [95]	validation_0-auc:1	validation_1-auc:0.992892
#
# [96]	validation_0-auc:1	validation_1-auc:0.992892
#
# [97]	validation_0-auc:1	validation_1-auc:0.992892
#
# [98]	validation_0-auc:1	validation_1-auc:0.992892
#
# [99]	validation_0-auc:1	validation_1-auc:0.992892
#
# [0]	validation_0-auc:0.993175	validation_1-auc:0.961209
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.994227	validation_1-auc:0.982433
#
# [2]	validation_0-auc:0.993619	validation_1-auc:0.978509
#
# [3]	validation_0-auc:0.996728	validation_1-auc:0.981184
#
# [4]	validation_0-auc:0.996681	validation_1-auc:0.97735
#
# [5]	validation_0-auc:0.997265	validation_1-auc:0.979757
#
# [6]	validation_0-auc:0.998808	validation_1-auc:0.980649
#
# [7]	validation_0-auc:0.999135	validation_1-auc:0.982254
#
# [8]	validation_0-auc:0.999346	validation_1-auc:0.981184
#
# [9]	validation_0-auc:0.999112	validation_1-auc:0.981006
#
# [10]	validation_0-auc:0.999252	validation_1-auc:0.981363
#
# [11]	validation_0-auc:0.999392	validation_1-auc:0.982433
#
# [12]	validation_0-auc:0.999486	validation_1-auc:0.983681
#
# [13]	validation_0-auc:0.999579	validation_1-auc:0.983324
#
# [14]	validation_0-auc:0.999579	validation_1-auc:0.983503
#
# [15]	validation_0-auc:0.999579	validation_1-auc:0.983681
#
# [16]	validation_0-auc:0.999673	validation_1-auc:0.982968
#
# [17]	validation_0-auc:0.999673	validation_1-auc:0.983859
#
# [18]	validation_0-auc:0.999673	validation_1-auc:0.984662
#
# [19]	validation_0-auc:0.999626	validation_1-auc:0.98484
#
# [20]	validation_0-auc:0.999766	validation_1-auc:0.98484
#
# [21]	validation_0-auc:0.999766	validation_1-auc:0.984484
#
# [22]	validation_0-auc:0.999673	validation_1-auc:0.984484
#
# [23]	validation_0-auc:0.999673	validation_1-auc:0.984662
#
# [24]	validation_0-auc:0.999766	validation_1-auc:0.985197
#
# [25]	validation_0-auc:0.999766	validation_1-auc:0.984662
#
# [26]	validation_0-auc:0.99986	validation_1-auc:0.985732
#
# [27]	validation_0-auc:0.999906	validation_1-auc:0.985732
#
# [28]	validation_0-auc:0.999953	validation_1-auc:0.986089
#
# [29]	validation_0-auc:0.999953	validation_1-auc:0.985019
#
# [30]	validation_0-auc:0.999953	validation_1-auc:0.985375
#
# [31]	validation_0-auc:1	validation_1-auc:0.985554
#
# [32]	validation_0-auc:1	validation_1-auc:0.985821
#
# [33]	validation_0-auc:1	validation_1-auc:0.985554
#
# [34]	validation_0-auc:1	validation_1-auc:0.985375
#
# [35]	validation_0-auc:1	validation_1-auc:0.985554
#
# [36]	validation_0-auc:1	validation_1-auc:0.986089
#
# [37]	validation_0-auc:1	validation_1-auc:0.98591
#
# [38]	validation_0-auc:1	validation_1-auc:0.98591
#
# [39]	validation_0-auc:1	validation_1-auc:0.986267
#
# [40]	validation_0-auc:1	validation_1-auc:0.986089
#
# [41]	validation_0-auc:1	validation_1-auc:0.986089
#
# [42]	validation_0-auc:1	validation_1-auc:0.985554
#
# [43]	validation_0-auc:1	validation_1-auc:0.985732
#
# [44]	validation_0-auc:1	validation_1-auc:0.985197
#
# [45]	validation_0-auc:1	validation_1-auc:0.985197
#
# [46]	validation_0-auc:1	validation_1-auc:0.985554
#
# [47]	validation_0-auc:1	validation_1-auc:0.985732
#
# [48]	validation_0-auc:1	validation_1-auc:0.985375
#
# [49]	validation_0-auc:1	validation_1-auc:0.985019
#
# [50]	validation_0-auc:1	validation_1-auc:0.985019
#
# [51]	validation_0-auc:1	validation_1-auc:0.985019
#
# [52]	validation_0-auc:1	validation_1-auc:0.98484
#
# [53]	validation_0-auc:1	validation_1-auc:0.984305
#
# [54]	validation_0-auc:1	validation_1-auc:0.984305
#
# [55]	validation_0-auc:1	validation_1-auc:0.984127
#
# [56]	validation_0-auc:1	validation_1-auc:0.983592
#
# [57]	validation_0-auc:1	validation_1-auc:0.983414
#
# [58]	validation_0-auc:1	validation_1-auc:0.983235
#
# [59]	validation_0-auc:1	validation_1-auc:0.983057
#
# [60]	validation_0-auc:1	validation_1-auc:0.983414
#
# [61]	validation_0-auc:1	validation_1-auc:0.983057
#
# [62]	validation_0-auc:1	validation_1-auc:0.982879
#
# [63]	validation_0-auc:1	validation_1-auc:0.9827
#
# [64]	validation_0-auc:1	validation_1-auc:0.9827
#
# [65]	validation_0-auc:1	validation_1-auc:0.9827
#
# [66]	validation_0-auc:1	validation_1-auc:0.982522
#
# [67]	validation_0-auc:1	validation_1-auc:0.982522
#
# [68]	validation_0-auc:1	validation_1-auc:0.982343
#
# [69]	validation_0-auc:1	validation_1-auc:0.982522
#
# Stopping. Best iteration:
# [39]	validation_0-auc:1	validation_1-auc:0.986267
#
#
# [0]	validation_0-auc:0.987029	validation_1-auc:0.966018
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.988065	validation_1-auc:0.967174
#
# [2]	validation_0-auc:0.991691	validation_1-auc:0.974971
#
# [3]	validation_0-auc:0.991893	validation_1-auc:0.981132
#
# [4]	validation_0-auc:0.995339	validation_1-auc:0.98402
#
# [5]	validation_0-auc:0.995429	validation_1-auc:0.983442
#
# [6]	validation_0-auc:0.996352	validation_1-auc:0.984598
#
# [7]	validation_0-auc:0.996622	validation_1-auc:0.984116
#
# [8]	validation_0-auc:0.997073	validation_1-auc:0.984116
#
# [9]	validation_0-auc:0.99696	validation_1-auc:0.984116
#
# [10]	validation_0-auc:0.997591	validation_1-auc:0.991625
#
# [11]	validation_0-auc:0.997906	validation_1-auc:0.992299
#
# [12]	validation_0-auc:0.998086	validation_1-auc:0.991721
#
# [13]	validation_0-auc:0.998086	validation_1-auc:0.992106
#
# [14]	validation_0-auc:0.998221	validation_1-auc:0.992491
#
# [15]	validation_0-auc:0.998176	validation_1-auc:0.992395
#
# [16]	validation_0-auc:0.998626	validation_1-auc:0.991721
#
# [17]	validation_0-auc:0.998694	validation_1-auc:0.991529
#
# [18]	validation_0-auc:0.999009	validation_1-auc:0.992684
#
# [19]	validation_0-auc:0.999054	validation_1-auc:0.993069
#
# [20]	validation_0-auc:0.999234	validation_1-auc:0.992876
#
# [21]	validation_0-auc:0.99937	validation_1-auc:0.993069
#
# [22]	validation_0-auc:0.99937	validation_1-auc:0.993261
#
# [23]	validation_0-auc:0.99946	validation_1-auc:0.993069
#
# [24]	validation_0-auc:0.999505	validation_1-auc:0.993261
#
# [25]	validation_0-auc:0.99964	validation_1-auc:0.993069
#
# [26]	validation_0-auc:0.999865	validation_1-auc:0.993261
#
# [27]	validation_0-auc:0.99991	validation_1-auc:0.992684
#
# [28]	validation_0-auc:0.99991	validation_1-auc:0.992491
#
# [29]	validation_0-auc:0.99991	validation_1-auc:0.992299
#
# [30]	validation_0-auc:0.99991	validation_1-auc:0.992299
#
# [31]	validation_0-auc:0.99991	validation_1-auc:0.992491
#
# [32]	validation_0-auc:0.99991	validation_1-auc:0.992106
#
# [33]	validation_0-auc:0.99991	validation_1-auc:0.992684
#
# [34]	validation_0-auc:0.99991	validation_1-auc:0.992299
#
# [35]	validation_0-auc:0.99991	validation_1-auc:0.992491
#
# [36]	validation_0-auc:0.99991	validation_1-auc:0.992106
#
# [37]	validation_0-auc:0.99991	validation_1-auc:0.992106
#
# [38]	validation_0-auc:0.999955	validation_1-auc:0.992491
#
# [39]	validation_0-auc:0.999955	validation_1-auc:0.992876
#
# [40]	validation_0-auc:0.999955	validation_1-auc:0.992491
#
# [41]	validation_0-auc:0.999955	validation_1-auc:0.992491
#
# [42]	validation_0-auc:0.999955	validation_1-auc:0.992876
#
# [43]	validation_0-auc:0.999955	validation_1-auc:0.992299
#
# [44]	validation_0-auc:0.999955	validation_1-auc:0.992491
#
# [45]	validation_0-auc:0.999955	validation_1-auc:0.992491
#
# [46]	validation_0-auc:0.999955	validation_1-auc:0.992876
#
# [47]	validation_0-auc:0.999955	validation_1-auc:0.992876
#
# [48]	validation_0-auc:0.999955	validation_1-auc:0.992684
#
# [49]	validation_0-auc:0.999955	validation_1-auc:0.992876
#
# [50]	validation_0-auc:0.999955	validation_1-auc:0.992876
#
# [51]	validation_0-auc:0.999955	validation_1-auc:0.993454
#
# [52]	validation_0-auc:0.999955	validation_1-auc:0.993454
#
# [53]	validation_0-auc:0.999955	validation_1-auc:0.993647
#
# [54]	validation_0-auc:0.999955	validation_1-auc:0.993454
#
# [55]	validation_0-auc:0.999955	validation_1-auc:0.993454
#
# [56]	validation_0-auc:0.999955	validation_1-auc:0.993454
#
# [57]	validation_0-auc:1	validation_1-auc:0.993454
#
# [58]	validation_0-auc:1	validation_1-auc:0.993261
#
# [59]	validation_0-auc:1	validation_1-auc:0.993261
#
# [60]	validation_0-auc:1	validation_1-auc:0.993454
#
# [61]	validation_0-auc:1	validation_1-auc:0.993647
#
# [62]	validation_0-auc:1	validation_1-auc:0.993647
#
# [63]	validation_0-auc:1	validation_1-auc:0.993647
#
# [64]	validation_0-auc:1	validation_1-auc:0.993647
#
# [65]	validation_0-auc:1	validation_1-auc:0.994032
#
# [66]	validation_0-auc:1	validation_1-auc:0.994032
#
# [67]	validation_0-auc:1	validation_1-auc:0.994032
#
# [68]	validation_0-auc:1	validation_1-auc:0.994032
#
# [69]	validation_0-auc:1	validation_1-auc:0.994032
#
# [70]	validation_0-auc:1	validation_1-auc:0.994224
#
# [71]	validation_0-auc:1	validation_1-auc:0.994224
#
# [72]	validation_0-auc:1	validation_1-auc:0.994224
#
# [73]	validation_0-auc:1	validation_1-auc:0.994224
#
# [74]	validation_0-auc:1	validation_1-auc:0.994224
#
# [75]	validation_0-auc:1	validation_1-auc:0.994224
#
# [76]	validation_0-auc:1	validation_1-auc:0.994417
#
# [77]	validation_0-auc:1	validation_1-auc:0.994417
#
# [78]	validation_0-auc:1	validation_1-auc:0.994417
#
# [79]	validation_0-auc:1	validation_1-auc:0.994417
#
# [80]	validation_0-auc:1	validation_1-auc:0.994417
#
# [81]	validation_0-auc:1	validation_1-auc:0.994609
#
# [82]	validation_0-auc:1	validation_1-auc:0.994417
#
# [83]	validation_0-auc:1	validation_1-auc:0.994802
#
# [84]	validation_0-auc:1	validation_1-auc:0.994802
#
# [85]	validation_0-auc:1	validation_1-auc:0.994802
#
# [86]	validation_0-auc:1	validation_1-auc:0.994802
#
# [87]	validation_0-auc:1	validation_1-auc:0.994802
#
# [88]	validation_0-auc:1	validation_1-auc:0.994802
#
# [89]	validation_0-auc:1	validation_1-auc:0.994802
#
# [90]	validation_0-auc:1	validation_1-auc:0.994609
#
# [91]	validation_0-auc:1	validation_1-auc:0.994802
#
# [92]	validation_0-auc:1	validation_1-auc:0.994802
#
# [93]	validation_0-auc:1	validation_1-auc:0.994802
#
# [94]	validation_0-auc:1	validation_1-auc:0.994802
#
# [95]	validation_0-auc:1	validation_1-auc:0.994802
#
# [96]	validation_0-auc:1	validation_1-auc:0.994802
#
# [97]	validation_0-auc:1	validation_1-auc:0.994609
#
# [98]	validation_0-auc:1	validation_1-auc:0.994802
#
# [99]	validation_0-auc:1	validation_1-auc:0.994802
#
# [0]	validation_0-auc:0.978033	validation_1-auc:0.942227
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.991287	validation_1-auc:0.959267
#
# [2]	validation_0-auc:0.993477	validation_1-auc:0.971843
#
# [3]	validation_0-auc:0.993246	validation_1-auc:0.979315
#
# [4]	validation_0-auc:0.994399	validation_1-auc:0.97977
#
# [5]	validation_0-auc:0.994652	validation_1-auc:0.981137
#
# [6]	validation_0-auc:0.995644	validation_1-auc:0.977128
#
# [7]	validation_0-auc:0.996082	validation_1-auc:0.977128
#
# [8]	validation_0-auc:0.99622	validation_1-auc:0.978312
#
# [9]	validation_0-auc:0.996266	validation_1-auc:0.977766
#
# [10]	validation_0-auc:0.995943	validation_1-auc:0.977857
#
# [11]	validation_0-auc:0.995897	validation_1-auc:0.979861
#
# [12]	validation_0-auc:0.995966	validation_1-auc:0.979953
#
# [13]	validation_0-auc:0.995874	validation_1-auc:0.978677
#
# [14]	validation_0-auc:0.996266	validation_1-auc:0.978677
#
# [15]	validation_0-auc:0.996312	validation_1-auc:0.978404
#
# [16]	validation_0-auc:0.99645	validation_1-auc:0.978404
#
# [17]	validation_0-auc:0.996727	validation_1-auc:0.980044
#
# [18]	validation_0-auc:0.996635	validation_1-auc:0.980044
#
# [19]	validation_0-auc:0.997003	validation_1-auc:0.980408
#
# [20]	validation_0-auc:0.997142	validation_1-auc:0.98059
#
# [21]	validation_0-auc:0.997096	validation_1-auc:0.980773
#
# [22]	validation_0-auc:0.997234	validation_1-auc:0.981137
#
# [23]	validation_0-auc:0.997603	validation_1-auc:0.981228
#
# [24]	validation_0-auc:0.997833	validation_1-auc:0.981866
#
# [25]	validation_0-auc:0.997833	validation_1-auc:0.981866
#
# [26]	validation_0-auc:0.997787	validation_1-auc:0.982231
#
# [27]	validation_0-auc:0.997972	validation_1-auc:0.982048
#
# [28]	validation_0-auc:0.997926	validation_1-auc:0.982231
#
# [29]	validation_0-auc:0.997972	validation_1-auc:0.983689
#
# [30]	validation_0-auc:0.997926	validation_1-auc:0.984053
#
# [31]	validation_0-auc:0.998202	validation_1-auc:0.985693
#
# [32]	validation_0-auc:0.99811	validation_1-auc:0.985693
#
# [33]	validation_0-auc:0.998387	validation_1-auc:0.985876
#
# [34]	validation_0-auc:0.99834	validation_1-auc:0.987151
#
# [35]	validation_0-auc:0.998387	validation_1-auc:0.987516
#
# [36]	validation_0-auc:0.998525	validation_1-auc:0.987516
#
# [37]	validation_0-auc:0.998571	validation_1-auc:0.987698
#
# [38]	validation_0-auc:0.998617	validation_1-auc:0.988245
#
# [39]	validation_0-auc:0.998663	validation_1-auc:0.988063
#
# [40]	validation_0-auc:0.998663	validation_1-auc:0.988245
#
# [41]	validation_0-auc:0.998617	validation_1-auc:0.988427
#
# [42]	validation_0-auc:0.998755	validation_1-auc:0.988609
#
# [43]	validation_0-auc:0.998755	validation_1-auc:0.988609
#
# [44]	validation_0-auc:0.998801	validation_1-auc:0.988792
#
# [45]	validation_0-auc:0.998847	validation_1-auc:0.989521
#
# [46]	validation_0-auc:0.998801	validation_1-auc:0.989156
#
# [47]	validation_0-auc:0.99894	validation_1-auc:0.989703
#
# [48]	validation_0-auc:0.999032	validation_1-auc:0.990067
#
# [49]	validation_0-auc:0.998986	validation_1-auc:0.99025
#
# [50]	validation_0-auc:0.999078	validation_1-auc:0.99025
#
# [51]	validation_0-auc:0.999078	validation_1-auc:0.990979
#
# [52]	validation_0-auc:0.999078	validation_1-auc:0.99107
#
# [53]	validation_0-auc:0.999216	validation_1-auc:0.990888
#
# [54]	validation_0-auc:0.999216	validation_1-auc:0.990705
#
# [55]	validation_0-auc:0.999262	validation_1-auc:0.991252
#
# [56]	validation_0-auc:0.999262	validation_1-auc:0.991252
#
# [57]	validation_0-auc:0.999355	validation_1-auc:0.99107
#
# [58]	validation_0-auc:0.999355	validation_1-auc:0.991434
#
# [59]	validation_0-auc:0.999401	validation_1-auc:0.991252
#
# [60]	validation_0-auc:0.999401	validation_1-auc:0.99107
#
# [61]	validation_0-auc:0.999401	validation_1-auc:0.99107
#
# [62]	validation_0-auc:0.999447	validation_1-auc:0.991434
#
# [63]	validation_0-auc:0.999447	validation_1-auc:0.991434
#
# [64]	validation_0-auc:0.999493	validation_1-auc:0.991981
#
# [65]	validation_0-auc:0.999585	validation_1-auc:0.992163
#
# [66]	validation_0-auc:0.999585	validation_1-auc:0.992163
#
# [67]	validation_0-auc:0.999539	validation_1-auc:0.992163
#
# [68]	validation_0-auc:0.999585	validation_1-auc:0.992163
#
# [69]	validation_0-auc:0.999631	validation_1-auc:0.992163
#
# [70]	validation_0-auc:0.999631	validation_1-auc:0.991981
#
# [71]	validation_0-auc:0.999631	validation_1-auc:0.992346
#
# [72]	validation_0-auc:0.999631	validation_1-auc:0.992346
#
# [73]	validation_0-auc:0.999631	validation_1-auc:0.99271
#
# [74]	validation_0-auc:0.999631	validation_1-auc:0.99271
#
# [75]	validation_0-auc:0.999631	validation_1-auc:0.992892
#
# [76]	validation_0-auc:0.999631	validation_1-auc:0.992892
#
# [77]	validation_0-auc:0.999631	validation_1-auc:0.992346
#
# [78]	validation_0-auc:0.999631	validation_1-auc:0.992346
#
# [79]	validation_0-auc:0.999631	validation_1-auc:0.993075
#
# [80]	validation_0-auc:0.999631	validation_1-auc:0.993075
#
# [81]	validation_0-auc:0.999631	validation_1-auc:0.993075
#
# [82]	validation_0-auc:0.999631	validation_1-auc:0.99271
#
# [83]	validation_0-auc:0.999631	validation_1-auc:0.993075
#
# [84]	validation_0-auc:0.999631	validation_1-auc:0.993075
#
# [85]	validation_0-auc:0.999631	validation_1-auc:0.993075
#
# [86]	validation_0-auc:0.999631	validation_1-auc:0.992892
#
# [87]	validation_0-auc:0.999631	validation_1-auc:0.993075
#
# [88]	validation_0-auc:0.999677	validation_1-auc:0.993075
#
# [89]	validation_0-auc:0.999677	validation_1-auc:0.992892
#
# [90]	validation_0-auc:0.999677	validation_1-auc:0.993075
#
# [91]	validation_0-auc:0.999723	validation_1-auc:0.993075
#
# [92]	validation_0-auc:0.999723	validation_1-auc:0.993075
#
# [93]	validation_0-auc:0.999677	validation_1-auc:0.993075
#
# [94]	validation_0-auc:0.999677	validation_1-auc:0.993257
#
# [95]	validation_0-auc:0.999723	validation_1-auc:0.992892
#
# [96]	validation_0-auc:0.999677	validation_1-auc:0.993257
#
# [97]	validation_0-auc:0.999723	validation_1-auc:0.992892
#
# [98]	validation_0-auc:0.999723	validation_1-auc:0.99271
#
# [99]	validation_0-auc:0.999723	validation_1-auc:0.99271
#
# [0]	validation_0-auc:0.983662	validation_1-auc:0.953629
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.992497	validation_1-auc:0.959961
#
# [2]	validation_0-auc:0.992427	validation_1-auc:0.97298
#
# [3]	validation_0-auc:0.993058	validation_1-auc:0.973069
#
# [4]	validation_0-auc:0.993385	validation_1-auc:0.972802
#
# [5]	validation_0-auc:0.996704	validation_1-auc:0.985286
#
# [6]	validation_0-auc:0.996704	validation_1-auc:0.98484
#
# [7]	validation_0-auc:0.997125	validation_1-auc:0.98484
#
# [8]	validation_0-auc:0.997032	validation_1-auc:0.985465
#
# [9]	validation_0-auc:0.998037	validation_1-auc:0.98591
#
# [10]	validation_0-auc:0.998317	validation_1-auc:0.985375
#
# [11]	validation_0-auc:0.998177	validation_1-auc:0.985732
#
# [12]	validation_0-auc:0.99834	validation_1-auc:0.98484
#
# [13]	validation_0-auc:0.998785	validation_1-auc:0.985019
#
# [14]	validation_0-auc:0.998738	validation_1-auc:0.985375
#
# [15]	validation_0-auc:0.998831	validation_1-auc:0.987159
#
# [16]	validation_0-auc:0.999112	validation_1-auc:0.986267
#
# [17]	validation_0-auc:0.999205	validation_1-auc:0.98591
#
# [18]	validation_0-auc:0.999392	validation_1-auc:0.986267
#
# [19]	validation_0-auc:0.999252	validation_1-auc:0.986624
#
# [20]	validation_0-auc:0.999252	validation_1-auc:0.987694
#
# [21]	validation_0-auc:0.999252	validation_1-auc:0.986445
#
# [22]	validation_0-auc:0.999346	validation_1-auc:0.987872
#
# [23]	validation_0-auc:0.999299	validation_1-auc:0.986802
#
# [24]	validation_0-auc:0.999299	validation_1-auc:0.986624
#
# [25]	validation_0-auc:0.999299	validation_1-auc:0.986089
#
# [26]	validation_0-auc:0.999252	validation_1-auc:0.986981
#
# [27]	validation_0-auc:0.999299	validation_1-auc:0.986267
#
# [28]	validation_0-auc:0.999252	validation_1-auc:0.98591
#
# [29]	validation_0-auc:0.999252	validation_1-auc:0.985554
#
# [30]	validation_0-auc:0.999159	validation_1-auc:0.985375
#
# [31]	validation_0-auc:0.999112	validation_1-auc:0.985019
#
# [32]	validation_0-auc:0.999065	validation_1-auc:0.985554
#
# [33]	validation_0-auc:0.999018	validation_1-auc:0.985554
#
# [34]	validation_0-auc:0.999159	validation_1-auc:0.985375
#
# [35]	validation_0-auc:0.999112	validation_1-auc:0.98484
#
# [36]	validation_0-auc:0.999159	validation_1-auc:0.98484
#
# [37]	validation_0-auc:0.999018	validation_1-auc:0.98484
#
# [38]	validation_0-auc:0.999159	validation_1-auc:0.984662
#
# [39]	validation_0-auc:0.999159	validation_1-auc:0.985019
#
# [40]	validation_0-auc:0.999159	validation_1-auc:0.985019
#
# [41]	validation_0-auc:0.999252	validation_1-auc:0.985019
#
# [42]	validation_0-auc:0.999299	validation_1-auc:0.985019
#
# [43]	validation_0-auc:0.999299	validation_1-auc:0.985019
#
# [44]	validation_0-auc:0.999346	validation_1-auc:0.98484
#
# [45]	validation_0-auc:0.999299	validation_1-auc:0.98484
#
# [46]	validation_0-auc:0.999346	validation_1-auc:0.985019
#
# [47]	validation_0-auc:0.999346	validation_1-auc:0.98484
#
# [48]	validation_0-auc:0.999346	validation_1-auc:0.985197
#
# [49]	validation_0-auc:0.999346	validation_1-auc:0.98484
#
# [50]	validation_0-auc:0.999392	validation_1-auc:0.98484
#
# [51]	validation_0-auc:0.999392	validation_1-auc:0.984662
#
# [52]	validation_0-auc:0.999392	validation_1-auc:0.985019
#
# Stopping. Best iteration:
# [22]	validation_0-auc:0.999346	validation_1-auc:0.987872
#
#
# [0]	validation_0-auc:0.980724	validation_1-auc:0.975452
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.98167	validation_1-auc:0.975838
#
# [2]	validation_0-auc:0.994325	validation_1-auc:0.981036
#
# [3]	validation_0-auc:0.994776	validation_1-auc:0.983731
#
# [4]	validation_0-auc:0.994798	validation_1-auc:0.983635
#
# [5]	validation_0-auc:0.994753	validation_1-auc:0.983635
#
# [6]	validation_0-auc:0.994596	validation_1-auc:0.984694
#
# [7]	validation_0-auc:0.994641	validation_1-auc:0.984694
#
# [8]	validation_0-auc:0.994866	validation_1-auc:0.984983
#
# [9]	validation_0-auc:0.995722	validation_1-auc:0.985175
#
# [10]	validation_0-auc:0.995631	validation_1-auc:0.985175
#
# [11]	validation_0-auc:0.995676	validation_1-auc:0.98556
#
# [12]	validation_0-auc:0.996127	validation_1-auc:0.985753
#
# [13]	validation_0-auc:0.996194	validation_1-auc:0.986715
#
# [14]	validation_0-auc:0.996375	validation_1-auc:0.986715
#
# [15]	validation_0-auc:0.996329	validation_1-auc:0.986715
#
# [16]	validation_0-auc:0.996465	validation_1-auc:0.99201
#
# [17]	validation_0-auc:0.996645	validation_1-auc:0.99201
#
# [18]	validation_0-auc:0.99669	validation_1-auc:0.991914
#
# [19]	validation_0-auc:0.996645	validation_1-auc:0.991817
#
# [20]	validation_0-auc:0.99678	validation_1-auc:0.991817
#
# [21]	validation_0-auc:0.99687	validation_1-auc:0.989892
#
# [22]	validation_0-auc:0.996892	validation_1-auc:0.989603
#
# [23]	validation_0-auc:0.997073	validation_1-auc:0.989411
#
# [24]	validation_0-auc:0.997163	validation_1-auc:0.991144
#
# [25]	validation_0-auc:0.997343	validation_1-auc:0.990951
#
# [26]	validation_0-auc:0.997433	validation_1-auc:0.990759
#
# [27]	validation_0-auc:0.997478	validation_1-auc:0.990373
#
# [28]	validation_0-auc:0.997388	validation_1-auc:0.987871
#
# [29]	validation_0-auc:0.997298	validation_1-auc:0.987871
#
# [30]	validation_0-auc:0.997388	validation_1-auc:0.990759
#
# [31]	validation_0-auc:0.997343	validation_1-auc:0.991529
#
# [32]	validation_0-auc:0.997298	validation_1-auc:0.991336
#
# [33]	validation_0-auc:0.997388	validation_1-auc:0.991721
#
# [34]	validation_0-auc:0.997568	validation_1-auc:0.991914
#
# [35]	validation_0-auc:0.997658	validation_1-auc:0.992684
#
# [36]	validation_0-auc:0.997838	validation_1-auc:0.992299
#
# [37]	validation_0-auc:0.997793	validation_1-auc:0.992491
#
# [38]	validation_0-auc:0.997928	validation_1-auc:0.992299
#
# [39]	validation_0-auc:0.998108	validation_1-auc:0.992299
#
# [40]	validation_0-auc:0.998154	validation_1-auc:0.992684
#
# [41]	validation_0-auc:0.998154	validation_1-auc:0.993839
#
# [42]	validation_0-auc:0.998289	validation_1-auc:0.993647
#
# [43]	validation_0-auc:0.998469	validation_1-auc:0.993647
#
# [44]	validation_0-auc:0.998514	validation_1-auc:0.993647
#
# [45]	validation_0-auc:0.998649	validation_1-auc:0.994417
#
# [46]	validation_0-auc:0.998604	validation_1-auc:0.994417
#
# [47]	validation_0-auc:0.998649	validation_1-auc:0.994417
#
# [48]	validation_0-auc:0.998784	validation_1-auc:0.994224
#
# [49]	validation_0-auc:0.998784	validation_1-auc:0.994609
#
# [50]	validation_0-auc:0.998829	validation_1-auc:0.994609
#
# [51]	validation_0-auc:0.998874	validation_1-auc:0.994417
#
# [52]	validation_0-auc:0.998874	validation_1-auc:0.994417
#
# [53]	validation_0-auc:0.998964	validation_1-auc:0.994032
#
# [54]	validation_0-auc:0.999009	validation_1-auc:0.994417
#
# [55]	validation_0-auc:0.999054	validation_1-auc:0.994032
#
# [56]	validation_0-auc:0.999099	validation_1-auc:0.994609
#
# [57]	validation_0-auc:0.999054	validation_1-auc:0.994994
#
# [58]	validation_0-auc:0.999144	validation_1-auc:0.994994
#
# [59]	validation_0-auc:0.999144	validation_1-auc:0.994994
#
# [60]	validation_0-auc:0.999099	validation_1-auc:0.994994
#
# [61]	validation_0-auc:0.999189	validation_1-auc:0.995187
#
# [62]	validation_0-auc:0.999189	validation_1-auc:0.995187
#
# [63]	validation_0-auc:0.999189	validation_1-auc:0.995187
#
# [64]	validation_0-auc:0.999234	validation_1-auc:0.995187
#
# [65]	validation_0-auc:0.999324	validation_1-auc:0.995187
#
# [66]	validation_0-auc:0.999279	validation_1-auc:0.995187
#
# [67]	validation_0-auc:0.999415	validation_1-auc:0.995187
#
# [68]	validation_0-auc:0.999415	validation_1-auc:0.995187
#
# [69]	validation_0-auc:0.999415	validation_1-auc:0.995187
#
# [70]	validation_0-auc:0.999415	validation_1-auc:0.995187
#
# [71]	validation_0-auc:0.99946	validation_1-auc:0.995187
#
# [72]	validation_0-auc:0.999415	validation_1-auc:0.995187
#
# [73]	validation_0-auc:0.99946	validation_1-auc:0.995187
#
# [74]	validation_0-auc:0.99946	validation_1-auc:0.995187
#
# [75]	validation_0-auc:0.99946	validation_1-auc:0.995187
#
# [76]	validation_0-auc:0.99946	validation_1-auc:0.995187
#
# [77]	validation_0-auc:0.99946	validation_1-auc:0.994994
#
# [78]	validation_0-auc:0.99955	validation_1-auc:0.995379
#
# [79]	validation_0-auc:0.99955	validation_1-auc:0.995379
#
# [80]	validation_0-auc:0.999595	validation_1-auc:0.995187
#
# [81]	validation_0-auc:0.999595	validation_1-auc:0.995187
#
# [82]	validation_0-auc:0.99964	validation_1-auc:0.995187
#
# [83]	validation_0-auc:0.99955	validation_1-auc:0.995187
#
# [84]	validation_0-auc:0.99964	validation_1-auc:0.995187
#
# [85]	validation_0-auc:0.99964	validation_1-auc:0.995379
#
# [86]	validation_0-auc:0.99964	validation_1-auc:0.995379
#
# [87]	validation_0-auc:0.99964	validation_1-auc:0.995379
#
# [88]	validation_0-auc:0.999685	validation_1-auc:0.995379
#
# [89]	validation_0-auc:0.999685	validation_1-auc:0.995187
#
# [90]	validation_0-auc:0.99964	validation_1-auc:0.995187
#
# [91]	validation_0-auc:0.99964	validation_1-auc:0.995187
#
# [92]	validation_0-auc:0.99973	validation_1-auc:0.995187
#
# [93]	validation_0-auc:0.99973	validation_1-auc:0.995187
#
# [94]	validation_0-auc:0.99973	validation_1-auc:0.995187
#
# [95]	validation_0-auc:0.99973	validation_1-auc:0.995187
#
# [96]	validation_0-auc:0.99973	validation_1-auc:0.995187
#
# [97]	validation_0-auc:0.99973	validation_1-auc:0.995187
#
# [98]	validation_0-auc:0.99973	validation_1-auc:0.995379
#
# [99]	validation_0-auc:0.99973	validation_1-auc:0.995187
#
# [0]	validation_0-auc:0.972663	validation_1-auc:0.957536
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.979532	validation_1-auc:0.969656
#
# [2]	validation_0-auc:0.981491	validation_1-auc:0.974941
#
# [3]	validation_0-auc:0.981675	validation_1-auc:0.974941
#
# [4]	validation_0-auc:0.981929	validation_1-auc:0.976308
#
# [5]	validation_0-auc:0.98156	validation_1-auc:0.974759
#
# [6]	validation_0-auc:0.981652	validation_1-auc:0.975943
#
# [7]	validation_0-auc:0.981652	validation_1-auc:0.976125
#
# [8]	validation_0-auc:0.985686	validation_1-auc:0.976854
#
# [9]	validation_0-auc:0.985363	validation_1-auc:0.976125
#
# [10]	validation_0-auc:0.985363	validation_1-auc:0.97649
#
# [11]	validation_0-auc:0.985317	validation_1-auc:0.97649
#
# [12]	validation_0-auc:0.985317	validation_1-auc:0.976672
#
# [13]	validation_0-auc:0.985317	validation_1-auc:0.976672
#
# [14]	validation_0-auc:0.985317	validation_1-auc:0.976672
#
# [15]	validation_0-auc:0.985133	validation_1-auc:0.975214
#
# [16]	validation_0-auc:0.985317	validation_1-auc:0.975761
#
# ...
#
# [76]	validation_0-auc:0.999955	validation_1-auc:0.994802
#
# [77]	validation_0-auc:0.999955	validation_1-auc:0.994802
#
# [78]	validation_0-auc:0.999955	validation_1-auc:0.994609
#
# [79]	validation_0-auc:0.999955	validation_1-auc:0.994609
#
# [80]	validation_0-auc:0.999955	validation_1-auc:0.994609
#
# [81]	validation_0-auc:0.999955	validation_1-auc:0.994802
#
# [82]	validation_0-auc:0.999955	validation_1-auc:0.994802
#
# [83]	validation_0-auc:0.999955	validation_1-auc:0.994802
#
# [84]	validation_0-auc:0.999955	validation_1-auc:0.994802
#
# [85]	validation_0-auc:0.999955	validation_1-auc:0.994802
#
# [86]	validation_0-auc:0.999955	validation_1-auc:0.994802
#
# [87]	validation_0-auc:0.999955	validation_1-auc:0.994802
#
# [88]	validation_0-auc:0.999955	validation_1-auc:0.994802
#
# [89]	validation_0-auc:0.999955	validation_1-auc:0.994802
#
# [90]	validation_0-auc:0.999955	validation_1-auc:0.994609
#
# [91]	validation_0-auc:0.999955	validation_1-auc:0.994609
#
# [92]	validation_0-auc:0.999955	validation_1-auc:0.994417
#
# [93]	validation_0-auc:0.999955	validation_1-auc:0.994417
#
# [94]	validation_0-auc:0.999955	validation_1-auc:0.994417
#
# [95]	validation_0-auc:0.999955	validation_1-auc:0.994417
#
# [96]	validation_0-auc:0.999955	validation_1-auc:0.994417
#
# [97]	validation_0-auc:0.999955	validation_1-auc:0.994417
#
# [98]	validation_0-auc:0.999955	validation_1-auc:0.994417
#
# [99]	validation_0-auc:0.999955	validation_1-auc:0.994417
#
# [0]	validation_0-auc:0.972271	validation_1-auc:0.905048
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.981629	validation_1-auc:0.950884
#
# [2]	validation_0-auc:0.988844	validation_1-auc:0.973574
#
# [3]	validation_0-auc:0.992509	validation_1-auc:0.982231
#
# [4]	validation_0-auc:0.992509	validation_1-auc:0.983324
#
# [5]	validation_0-auc:0.992509	validation_1-auc:0.98296
#
# [6]	validation_0-auc:0.993869	validation_1-auc:0.981502
#
# [7]	validation_0-auc:0.994768	validation_1-auc:0.981137
#
# [8]	validation_0-auc:0.994468	validation_1-auc:0.980408
#
# [9]	validation_0-auc:0.994699	validation_1-auc:0.981319
#
# [10]	validation_0-auc:0.99509	validation_1-auc:0.980773
#
# [11]	validation_0-auc:0.995044	validation_1-auc:0.981137
#
# [12]	validation_0-auc:0.995183	validation_1-auc:0.981684
#
# [13]	validation_0-auc:0.996128	validation_1-auc:0.98378
#
# [14]	validation_0-auc:0.995667	validation_1-auc:0.984144
#
# [15]	validation_0-auc:0.995943	validation_1-auc:0.984418
#
# [16]	validation_0-auc:0.995897	validation_1-auc:0.984418
#
# [17]	validation_0-auc:0.996312	validation_1-auc:0.985693
#
# [18]	validation_0-auc:0.996727	validation_1-auc:0.986787
#
# [19]	validation_0-auc:0.996727	validation_1-auc:0.986787
#
# [20]	validation_0-auc:0.996819	validation_1-auc:0.987698
#
# [21]	validation_0-auc:0.996819	validation_1-auc:0.988245
#
# [22]	validation_0-auc:0.997142	validation_1-auc:0.988063
#
# [23]	validation_0-auc:0.99728	validation_1-auc:0.987972
#
# [24]	validation_0-auc:0.996911	validation_1-auc:0.988154
#
# [25]	validation_0-auc:0.997695	validation_1-auc:0.988883
#
# [26]	validation_0-auc:0.997787	validation_1-auc:0.989338
#
# [27]	validation_0-auc:0.998156	validation_1-auc:0.989521
#
# [28]	validation_0-auc:0.998387	validation_1-auc:0.990067
#
# [29]	validation_0-auc:0.998755	validation_1-auc:0.989703
#
# [30]	validation_0-auc:0.998847	validation_1-auc:0.990067
#
# [31]	validation_0-auc:0.998801	validation_1-auc:0.989885
#
# [32]	validation_0-auc:0.998894	validation_1-auc:0.989885
#
# [33]	validation_0-auc:0.998847	validation_1-auc:0.99025
#
# [34]	validation_0-auc:0.998847	validation_1-auc:0.990341
#
# [35]	validation_0-auc:0.99894	validation_1-auc:0.991252
#
# [36]	validation_0-auc:0.998894	validation_1-auc:0.991434
#
# [37]	validation_0-auc:0.998755	validation_1-auc:0.991981
#
# [38]	validation_0-auc:0.998709	validation_1-auc:0.991981
#
# [39]	validation_0-auc:0.998847	validation_1-auc:0.992346
#
# [40]	validation_0-auc:0.998986	validation_1-auc:0.992528
#
# [41]	validation_0-auc:0.999078	validation_1-auc:0.992163
#
# [42]	validation_0-auc:0.99917	validation_1-auc:0.992163
#
# [43]	validation_0-auc:0.999032	validation_1-auc:0.992163
#
# [44]	validation_0-auc:0.999124	validation_1-auc:0.992163
#
# [45]	validation_0-auc:0.999124	validation_1-auc:0.991981
#
# [46]	validation_0-auc:0.999124	validation_1-auc:0.991799
#
# [47]	validation_0-auc:0.999124	validation_1-auc:0.991981
#
# [48]	validation_0-auc:0.999124	validation_1-auc:0.991981
#
# [49]	validation_0-auc:0.999078	validation_1-auc:0.991981
#
# [50]	validation_0-auc:0.999078	validation_1-auc:0.991799
#
# [51]	validation_0-auc:0.999032	validation_1-auc:0.991799
#
# [52]	validation_0-auc:0.999032	validation_1-auc:0.991799
#
# [53]	validation_0-auc:0.999032	validation_1-auc:0.991617
#
# [54]	validation_0-auc:0.999032	validation_1-auc:0.991799
#
# [55]	validation_0-auc:0.999032	validation_1-auc:0.991981
#
# [56]	validation_0-auc:0.999032	validation_1-auc:0.991981
#
# [57]	validation_0-auc:0.999078	validation_1-auc:0.991981
#
# [58]	validation_0-auc:0.999032	validation_1-auc:0.991981
#
# [59]	validation_0-auc:0.998986	validation_1-auc:0.992163
#
# [60]	validation_0-auc:0.999032	validation_1-auc:0.992346
#
# [61]	validation_0-auc:0.998894	validation_1-auc:0.99271
#
# [62]	validation_0-auc:0.99894	validation_1-auc:0.99271
#
# [63]	validation_0-auc:0.99894	validation_1-auc:0.992346
#
# [64]	validation_0-auc:0.998894	validation_1-auc:0.992346
#
# [65]	validation_0-auc:0.998847	validation_1-auc:0.992346
#
# [66]	validation_0-auc:0.998801	validation_1-auc:0.992528
#
# [67]	validation_0-auc:0.998801	validation_1-auc:0.992528
#
# [68]	validation_0-auc:0.998894	validation_1-auc:0.99271
#
# [69]	validation_0-auc:0.998894	validation_1-auc:0.993075
#
# [70]	validation_0-auc:0.998847	validation_1-auc:0.992892
#
# [71]	validation_0-auc:0.998801	validation_1-auc:0.992892
#
# [72]	validation_0-auc:0.998894	validation_1-auc:0.993075
#
# [73]	validation_0-auc:0.998847	validation_1-auc:0.992892
#
# [74]	validation_0-auc:0.999032	validation_1-auc:0.992892
#
# [75]	validation_0-auc:0.998986	validation_1-auc:0.992892
#
# [76]	validation_0-auc:0.999124	validation_1-auc:0.992892
#
# [77]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [78]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [79]	validation_0-auc:0.999078	validation_1-auc:0.992892
#
# [80]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [81]	validation_0-auc:0.99917	validation_1-auc:0.993075
#
# [82]	validation_0-auc:0.99917	validation_1-auc:0.993075
#
# [83]	validation_0-auc:0.99917	validation_1-auc:0.993075
#
# [84]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [85]	validation_0-auc:0.99917	validation_1-auc:0.993075
#
# [86]	validation_0-auc:0.99917	validation_1-auc:0.993075
#
# [87]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [88]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [89]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [90]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [91]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [92]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [93]	validation_0-auc:0.999124	validation_1-auc:0.992892
#
# [94]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [95]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [96]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [97]	validation_0-auc:0.999124	validation_1-auc:0.993075
#
# [98]	validation_0-auc:0.99917	validation_1-auc:0.993075
#
# [99]	validation_0-auc:0.99917	validation_1-auc:0.993075
#
# Stopping. Best iteration:
# [69]	validation_0-auc:0.998894	validation_1-auc:0.993075
#
#
# [0]	validation_0-auc:0.981839	validation_1-auc:0.951489
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.991726	validation_1-auc:0.965133
#
# [2]	validation_0-auc:0.996003	validation_1-auc:0.964152
#
# [3]	validation_0-auc:0.998294	validation_1-auc:0.972445
#
# [4]	validation_0-auc:0.997639	validation_1-auc:0.973159
#
# [5]	validation_0-auc:0.998154	validation_1-auc:0.97084
#
# [6]	validation_0-auc:0.998107	validation_1-auc:0.969948
#
# [7]	validation_0-auc:0.99806	validation_1-auc:0.969592
#
# [8]	validation_0-auc:0.99778	validation_1-auc:0.970037
#
# [9]	validation_0-auc:0.998107	validation_1-auc:0.970751
#
# [10]	validation_0-auc:0.99806	validation_1-auc:0.970394
#
# [11]	validation_0-auc:0.9982	validation_1-auc:0.970394
#
# [12]	validation_0-auc:0.998247	validation_1-auc:0.969859
#
# [13]	validation_0-auc:0.998107	validation_1-auc:0.969859
#
# [14]	validation_0-auc:0.998247	validation_1-auc:0.969859
#
# [15]	validation_0-auc:0.998317	validation_1-auc:0.969413
#
# [16]	validation_0-auc:0.997896	validation_1-auc:0.970305
#
# [17]	validation_0-auc:0.997943	validation_1-auc:0.971375
#
# [18]	validation_0-auc:0.99785	validation_1-auc:0.970483
#
# [19]	validation_0-auc:0.998317	validation_1-auc:0.971375
#
# [20]	validation_0-auc:0.998037	validation_1-auc:0.972178
#
# [21]	validation_0-auc:0.998411	validation_1-auc:0.971999
#
# [22]	validation_0-auc:0.998644	validation_1-auc:0.972356
#
# [23]	validation_0-auc:0.998551	validation_1-auc:0.971643
#
# [24]	validation_0-auc:0.998621	validation_1-auc:0.972088
#
# [25]	validation_0-auc:0.998714	validation_1-auc:0.972445
#
# [26]	validation_0-auc:0.998668	validation_1-auc:0.972267
#
# [27]	validation_0-auc:0.998714	validation_1-auc:0.972267
#
# [28]	validation_0-auc:0.998901	validation_1-auc:0.972445
#
# [29]	validation_0-auc:0.998855	validation_1-auc:0.972624
#
# [30]	validation_0-auc:0.998714	validation_1-auc:0.972802
#
# [31]	validation_0-auc:0.999018	validation_1-auc:0.97298
#
# [32]	validation_0-auc:0.999065	validation_1-auc:0.973159
#
# [33]	validation_0-auc:0.999065	validation_1-auc:0.97298
#
# [34]	validation_0-auc:0.999299	validation_1-auc:0.973337
#
# [35]	validation_0-auc:0.999299	validation_1-auc:0.973337
#
# [36]	validation_0-auc:0.999299	validation_1-auc:0.973337
#
# [37]	validation_0-auc:0.999299	validation_1-auc:0.973872
#
# [38]	validation_0-auc:0.999299	validation_1-auc:0.973604
#
# [39]	validation_0-auc:0.999299	validation_1-auc:0.976904
#
# [40]	validation_0-auc:0.999299	validation_1-auc:0.976904
#
# [41]	validation_0-auc:0.999392	validation_1-auc:0.976904
#
# [42]	validation_0-auc:0.999299	validation_1-auc:0.976904
#
# [43]	validation_0-auc:0.999299	validation_1-auc:0.976547
#
# [44]	validation_0-auc:0.999299	validation_1-auc:0.976547
#
# [45]	validation_0-auc:0.999299	validation_1-auc:0.976547
#
# [46]	validation_0-auc:0.999299	validation_1-auc:0.976547
#
# [47]	validation_0-auc:0.999392	validation_1-auc:0.976012
#
# [48]	validation_0-auc:0.999346	validation_1-auc:0.976012
#
# [49]	validation_0-auc:0.999392	validation_1-auc:0.975477
#
# [50]	validation_0-auc:0.999392	validation_1-auc:0.975477
#
# [51]	validation_0-auc:0.999392	validation_1-auc:0.974942
#
# [52]	validation_0-auc:0.999392	validation_1-auc:0.974942
#
# [53]	validation_0-auc:0.999392	validation_1-auc:0.97512
#
# [54]	validation_0-auc:0.999392	validation_1-auc:0.974318
#
# [55]	validation_0-auc:0.999392	validation_1-auc:0.974318
#
# [56]	validation_0-auc:0.999392	validation_1-auc:0.974318
#
# [57]	validation_0-auc:0.999439	validation_1-auc:0.974675
#
# [58]	validation_0-auc:0.999392	validation_1-auc:0.974675
#
# [59]	validation_0-auc:0.999439	validation_1-auc:0.974675
#
# [60]	validation_0-auc:0.999439	validation_1-auc:0.974675
#
# [61]	validation_0-auc:0.999486	validation_1-auc:0.974675
#
# [62]	validation_0-auc:0.999392	validation_1-auc:0.974675
#
# [63]	validation_0-auc:0.999486	validation_1-auc:0.974853
#
# [64]	validation_0-auc:0.999486	validation_1-auc:0.975031
#
# [65]	validation_0-auc:0.999486	validation_1-auc:0.975031
#
# [66]	validation_0-auc:0.999486	validation_1-auc:0.975031
#
# [67]	validation_0-auc:0.999486	validation_1-auc:0.974853
#
# [68]	validation_0-auc:0.999533	validation_1-auc:0.974853
#
# [69]	validation_0-auc:0.999533	validation_1-auc:0.974853
#
# Stopping. Best iteration:
# [39]	validation_0-auc:0.999299	validation_1-auc:0.976904
#
#
# [0]	validation_0-auc:0.96897	validation_1-auc:0.960724
#
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
#
# [1]	validation_0-auc:0.980251	validation_1-auc:0.969099
#
# [2]	validation_0-auc:0.980499	validation_1-auc:0.969195
#
# [3]	validation_0-auc:0.984395	validation_1-auc:0.975838
#
# [4]	validation_0-auc:0.9848	validation_1-auc:0.980266
#
# [5]	validation_0-auc:0.9848	validation_1-auc:0.980266
#
# [6]	validation_0-auc:0.987074	validation_1-auc:0.981036
#
# [7]	validation_0-auc:0.988043	validation_1-auc:0.983539
#
# [8]	validation_0-auc:0.988943	validation_1-auc:0.984501
#
# [9]	validation_0-auc:0.989732	validation_1-auc:0.985849
#
# [10]	validation_0-auc:0.992434	validation_1-auc:0.99124
#
# [11]	validation_0-auc:0.993425	validation_1-auc:0.99278
#
# [12]	validation_0-auc:0.994978	validation_1-auc:0.992973
#
# [13]	validation_0-auc:0.995159	validation_1-auc:0.992395
#
# [14]	validation_0-auc:0.995384	validation_1-auc:0.993261
#
# [15]	validation_0-auc:0.995767	validation_1-auc:0.992491
#
# [16]	validation_0-auc:0.995992	validation_1-auc:0.992106
#
# [17]	validation_0-auc:0.996127	validation_1-auc:0.993839
#
# [18]	validation_0-auc:0.996127	validation_1-auc:0.994224
#
# [19]	validation_0-auc:0.996532	validation_1-auc:0.993839
#
# [20]	validation_0-auc:0.996532	validation_1-auc:0.993647
#
# [21]	validation_0-auc:0.996802	validation_1-auc:0.993454
#
# [22]	validation_0-auc:0.996983	validation_1-auc:0.993454
#
# [23]	validation_0-auc:0.997253	validation_1-auc:0.993454
#
# [24]	validation_0-auc:0.997523	validation_1-auc:0.994032
#
# [25]	validation_0-auc:0.997703	validation_1-auc:0.993839
#
# [26]	validation_0-auc:0.997838	validation_1-auc:0.993839
#
# [27]	validation_0-auc:0.998018	validation_1-auc:0.993647
#
# [28]	validation_0-auc:0.998063	validation_1-auc:0.994417
#
# [29]	validation_0-auc:0.998199	validation_1-auc:0.994609
#
# [30]	validation_0-auc:0.998289	validation_1-auc:0.994994
#
# [31]	validation_0-auc:0.998289	validation_1-auc:0.995187
#
# [32]	validation_0-auc:0.998469	validation_1-auc:0.994994
#
# [33]	validation_0-auc:0.998649	validation_1-auc:0.995187
#
# [34]	validation_0-auc:0.998649	validation_1-auc:0.994609
#
# [35]	validation_0-auc:0.998604	validation_1-auc:0.995572
#
# [36]	validation_0-auc:0.998649	validation_1-auc:0.995187
#
# [37]	validation_0-auc:0.998739	validation_1-auc:0.994609
#
# [38]	validation_0-auc:0.998649	validation_1-auc:0.995187
#
# [39]	validation_0-auc:0.998739	validation_1-auc:0.994609
#
# [40]	validation_0-auc:0.998829	validation_1-auc:0.994417
#
# [41]	validation_0-auc:0.998874	validation_1-auc:0.994994
#
# [42]	validation_0-auc:0.998874	validation_1-auc:0.994802
#
# [43]	validation_0-auc:0.998919	validation_1-auc:0.994802
#
# [44]	validation_0-auc:0.998919	validation_1-auc:0.994802
#
# [45]	validation_0-auc:0.999054	validation_1-auc:0.994802
#
# [46]	validation_0-auc:0.999054	validation_1-auc:0.994802
#
# [47]	validation_0-auc:0.999054	validation_1-auc:0.994224
#
# [48]	validation_0-auc:0.999144	validation_1-auc:0.994802
#
# [49]	validation_0-auc:0.999099	validation_1-auc:0.994609
#
# [50]	validation_0-auc:0.999099	validation_1-auc:0.995379
#
# [51]	validation_0-auc:0.999099	validation_1-auc:0.995379
#
# [52]	validation_0-auc:0.999054	validation_1-auc:0.995572
#
# [53]	validation_0-auc:0.999099	validation_1-auc:0.995572
#
# [54]	validation_0-auc:0.999099	validation_1-auc:0.995572
#
# [55]	validation_0-auc:0.999144	validation_1-auc:0.995572
#
# [56]	validation_0-auc:0.999144	validation_1-auc:0.995572
#
# [57]	validation_0-auc:0.999099	validation_1-auc:0.995572
#
# [58]	validation_0-auc:0.999144	validation_1-auc:0.995379
#
# [59]	validation_0-auc:0.999144	validation_1-auc:0.995379
#
# [60]	validation_0-auc:0.999099	validation_1-auc:0.995379
#
# [61]	validation_0-auc:0.999099	validation_1-auc:0.995379
#
# [62]	validation_0-auc:0.999144	validation_1-auc:0.995379
#
# [63]	validation_0-auc:0.999099	validation_1-auc:0.995379
#
# [64]	validation_0-auc:0.999054	validation_1-auc:0.995187
#
# [65]	validation_0-auc:0.999054	validation_1-auc:0.994802
#
# Stopping. Best iteration:
# [35]	validation_0-auc:0.998604	validation_1-auc:0.995572
#
#
# 100%|██████████| 50/50 [02:25<00:00,  2.91s/it, best loss: -0.9936926860623029]
# best: {'colsample_bytree': 0.5002195025833651, 'learning_rate': 0.10444230837795263, 'max_depth': 13.0, 'min_child_weight': 4.0}
